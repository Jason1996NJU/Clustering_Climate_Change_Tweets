# %% [markdown]
# # Topic Modeling, Dimensionality Reduction, and K-means Clustering

# %% [markdown]
# - This notebook continues from the **Project_04_Classifier_R1** notebook, where the tweets were classified as climate change "believer" or "denier" tweets.
# - Before topic modeling is performed, some preliminary steps will be taken
#     1. Tweet sentiment will be determined for each tweet. They will be interpreted as either positive, neutral, or negative.
#     2. The user location for each tweet will be simplified into two groups: US or Other. Tweets that were created in the US will be focused on for this project.
# - In order to produce relevant and informative topics, it was determined that the most important words of each tweet were the nouns. Therefore, each word of each tweet will be tagged with a part of speech and the nouns will be extracted and analyzed.
# - Topic modeling will be performed using NMF and TFIDF vectorization.
#     - 30 topics will be generated.
# - PCA will then be used to perform dimensionality reduction and prepare the topic-document matrix for clustering.
#     - A scree plot and cumulative explained variance plot will be used to determine the ideal number of principle components.
# - Finally, K-means clustering will be performed.
#     - Inertia and silhouette scores will be used to identify the optimum number of clusters, and each tweet will be grouped into a cluster.
#     - EDA will be performed to see how tweet sentiment, US regions, and believers vs deniers are distributed throughout each cluster.
#     - Further analysis will be done to determine which topics are most prevalent within each cluster.

# %%
import pickle
import re
import string
import pandas as pd
import numpy as np
from collections import defaultdict
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid")
from tqdm.notebook import tqdm

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 270)
pd.set_option('display.precision', 5)

import spacy
import nltk
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

from textblob import TextBlob
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity

# gensim
import gensim
from gensim import corpora, models, similarities, matutils

# logging for gensim (set to INFO)
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# # Load `tweets_classified` from "Project_04_Classifier_R1" notebook

# %%
with open('Data/tweets_classified_logit.pkl','rb') as read_file:
    tweets_classified = pickle.load(read_file)

# %% [markdown]
# # Document Preprocessing

# %% [markdown]
# - Document preprocessing will involve the following steps (and will be executed with various functions):
#     - Cleaning (through `tweet_preprocessor`)
#         - remove line breaks
#         - remove URL's
#         - remove numbers
#         - remove capital letters and punctuation
#     - Lemmatization (through `tweet_tokenizer`)
#     - Tokenization (through `tweet_tokenizer`)

# %%
def tweet_preprocessor(tweet):

    '''
    Takes in tweet and cleans it by removing line breaks,
    URL's, emojis, numbers, capital letters, and punctuation.
    '''

    tweet = tweet.replace('\n', ' ') # remove line breaks
    tweet = re.sub(r"\bhttps://t.co/\w+", '', tweet) # remove URL's
    tweet = re.sub('\w*\d\w*', ' ', tweet) # remove numbers
    tweet = re.sub('[%s]' % re.escape(string.punctuation), ' ', tweet.lower()) # remove capital letters and punctuation
    
    return tweet

# %%
# create a spaCy tokenizer
spacy.load('en')
lemmatizer = spacy.lang.en.English()

def tweet_tokenizer(doc):
    
    '''
    Takes in tweet, tokenizes words, then lemmatizes tokens
    '''
    
    tokens = lemmatizer(doc)
    return [token.lemma_ for token in tokens]

# %%
preprocessed_tweet = []

for index, values in tqdm(tweets_classified['full_text'].iteritems()):
    preprocessed = tweet_preprocessor(values)
    tokenized = tweet_tokenizer(preprocessed)
    preprocessed_tweet.append(tokenized)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
# Remove spaces from each list

preprocessed_pretweets = []
preprocessed_tweets = []

for tweet in tqdm(preprocessed_tweet):
    for word in tweet:
        if ' ' in word:
            pass
        else:
            preprocessed_pretweets.append(word)
    preprocessed_tweets.append(preprocessed_pretweets)
    preprocessed_pretweets = []
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4225416.0), HTML(value='')))

# %%
tweets_classified.insert(3, column = 'preprocessed_text', value = preprocessed_tweets)

# %% [markdown]
# # Determine sentiment of each tweet using TextBlob

# %%
# Convert lists back to strings so that sentiment can be determined

preprocessed_string, preprocessed_strings = '', []

for tweets in tqdm(preprocessed_tweets):
    for word in tweets:
        preprocessed_string += word + ' '
    preprocessed_strings.append(preprocessed_string)
    preprocessed_string = ''
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4225416.0), HTML(value='')))

# %%
def get_tweet_sentiment(tweet): 
    ''' 
    Utility function to classify sentiment of passed tweet 
    using textblob's sentiment method 
    '''
    # create TextBlob object of passed tweet text 
    analysis = TextBlob(tweet) 
    # set sentiment 
    if analysis.sentiment.polarity > 0: 
        return 'positive'
    elif analysis.sentiment.polarity == 0: 
        return 'neutral'
    else: 
        return 'negative'

# %%
tweet_sentiment = [get_tweet_sentiment(tweet) for tweet in tqdm(preprocessed_strings)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4225416.0), HTML(value='')))

# %%
tweets_classified.insert(3, column = 'Tweet_Sentiment', value = tweet_sentiment)

# %%
# Quick look at breakdown of tweet sentiment for believers and deniers

tweets_sentiment = tweets_classified.groupby('Believer_or_Denier')['Tweet_Sentiment'].value_counts()
tweets_sentiment
# Out:
# Believer_or_Denier  Tweet_Sentiment
# 0.0                 positive           1646561
#                     neutral            1380910
#                     negative            779385
# 1.0                 positive            156083
#                     neutral             138692
#                     negative            123785
# Name: Tweet_Sentiment, dtype: int64

# %% [markdown]
# # Split Tweets by Geographic Location (US vs World)

# %%
us_abbrevs = [
              'US', 'USA', 'United States',
              'Alabama','AL','Alaska','AK','Arizona','AZ','Arkansas','AR',
              'California','CA','Colorado','CO','Connecticut','CT',
              'Delaware','DE',
              'Florida','FL',
              'Georgia','GA',
              'Hawaii','HI',
              'Idaho','ID','Illinois','IL','Indiana','IN','Iowa','IA',
              'Kansas','KS','Kentucky','KY',
              'Louisiana','LA',
              'Maine','ME','Maryland','MD','Massachusetts','MA','Michigan','MI',
              'Minnesota','MN','Mississippi','MS','Missouri','MO','Montana','MT',
              'Nebraska','NE','Nevada','NV','New Hampshire','NH','New Jersey','NJ',
              'New Mexico','NM','New York','NY','North Carolina','NC','North Dakota','ND',
              'Ohio','OH','Oklahoma','OK','Oregon','OR',
              'Pennsylvania','PA',
              'Rhode Island','RI',
              'South Carolina','SC','South Dakota','SD',
              'Tennessee','TN','Texas','TX',
              'Utah','UT',
              'Vermont','VT','Virginia','VA',
              'Washington','WA','West Virginia','WV','Wisconsin','WI','Wyoming','WY',
              'District of Columbia','DC'
             ]

# %%
# Identify rows that have a US user location, and put them into location_dict

location_dict = {}

for index, rows in tqdm(tweets_classified['User_Location'].iteritems()):
    for loc in us_abbrevs:
        if str(loc) in str(rows):
            location_dict[index] = 'US'
            continue
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
location_df = pd.DataFrame(list(location_dict.values()), index = list(location_dict.keys()))

# %%
tweets_classified['Merge_Index'] = tweets_classified.index
location_df['Merge_Index'] = location_df.index

# %%
# Insert updated user location (i.e. US or other) into tweets_classified

tweets_classified_loc = tweets_classified.merge(location_df, how='left', on='Merge_Index')

# %%
tweets_classified_loc.rename(columns={0:'US_or_Other'}, inplace=True)

# %%
tweets_classified_loc['US_or_Other'] = tweets_classified_loc['US_or_Other'].replace(np.nan,'Other')

# %%
tweets_classified_US = tweets_classified_loc[tweets_classified_loc['US_or_Other'] == 'US']

# %%
tweets_classified_Other = tweets_classified_loc[tweets_classified_loc['US_or_Other'] == 'Other']

# %% [markdown]
# ## Save `tweets_classified_US` and `tweets_classified_Other` as pickle files

# %% [markdown]
# - These files will be used in the **Project_04_EDA** notebook.

# %%
# with open('Data/tweets_classified_US.pkl', 'wb') as to_write:
#     pickle.dump(tweets_classified_US, to_write)

# %%
# with open('Data/tweets_classified_Other.pkl', 'wb') as to_write:
#     pickle.dump(tweets_classified_Other, to_write)

# %% [markdown]
# ---

# %%
# with open('tweets_classified_US_2017.pkl','rb') as read_file:
#     tweets_classified_US_2017 = pickle.load(read_file)

# with open('tweets_classified_US_2018.pkl','rb') as read_file:
#     tweets_classified_US_2018 = pickle.load(read_file)

# with open('tweets_classified_US_2019.pkl','rb') as read_file:
#     tweets_classified_US_2019 = pickle.load(read_file)

# %% [markdown]
# ---

# %% [markdown]
# # Part of Speech Tagging

# %% [markdown]
# - To determine the topic of each tweet, it makes sense to focus on the nouns. Nouns will be extracted from each tweet and used for topic modeling.

# %%
def get_nouns(tweet_df):

    tweet_series = tweet_df['preprocessed_text']
        
    pos_list, pos_prelist = [], []
    
    for index, tweet in tqdm(tweet_series.iteritems()):
        pos_pair = pos_tag(tweet)
        pos_prelist.append(pos_pair)
    pos_list.append(pos_prelist)
    pos_prelist = []

    nouns_list, nouns_prelist = [], []

    for second_bracket in tqdm(pos_list):
        for tweet in second_bracket:
            for word in tweet:
                if word[1] == 'NN':
                    nouns_prelist.append(word[0])
                elif word[1] == 'NNS':
                    nouns_prelist.append(word[0])
                elif word[1] == 'NNP':
                    nouns_prelist.append(word[0])
                elif word[1] == 'NNPS':
                    nouns_prelist.append(word[0])
            nouns_list.append(nouns_prelist)
            nouns_prelist = []

    noun_tweet, noun_tweets = '', []

    for tweets in tqdm(nouns_list):
        for noun in tweets:
            noun_tweet += noun + ' '
        noun_tweets.append(noun_tweet)
        noun_tweet = ''
        
    return tweet_series, pos_list, nouns_list, noun_tweets

# %%
tweet_series, pos_list, nouns_list, noun_tweets = get_nouns(tweets_classified_US)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1235350.0), HTML(value='')))

# %%
len(nouns_list)
# Out:
# 1235350

# %%
# noun_tweets17 = get_nouns(tweets_classified_US_2017)
# noun_tweets18 = get_nouns(tweets_classified_US_2018)
# noun_tweets19 = get_nouns(tweets_classified_US_2019)

# %% [markdown]
# # Topic Modeling
# - NMF will be used to determine top 30 topics from the tweets
# - TFIDF vectorization will be used with the following parameters:
#     - ngrams of length 2 or 3
#     - words/phrases must show up at least 3 times
#     - words/phrases cannot show up in more than 95% of the tweets
#     - stop words include standard English stop words and phrases such as "climate change" and "global warming"

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '",topic_names[ix],"'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
def NMF_model(tweet_df, tweets_list, no_topics):
    
    add_stop_words = ['climate change', 'climate', 'global warming', 'amp', 'climatechange', 'global', 'warming', 
                      'globalwarming', 'just', 'climateaction', 'change', 'really', 'eco', 'stevennbeck', 'boomerscomics', 'comics']
    new_stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)
    
    vectorizer = TfidfVectorizer(ngram_range = (2,3), max_df = 0.95, min_df = 3, stop_words=new_stop_words)
    doc_word_nmf = vectorizer.fit_transform(tweets_list)
    nmf_model = NMF(no_topics)
    doc_topic_nmf = nmf_model.fit_transform(doc_word_nmf)
    
    topics_list = display_topics(nmf_model, vectorizer.get_feature_names(), 10)
    
    columns = ['Topic_' + str(i) for i in range(no_topics)]
    H = pd.DataFrame(doc_topic_nmf.round(5), index = tweet_df.index, columns = columns)
    H.insert(0, column = 'full_text', value = tweet_df['full_text']) 
    
    return topics_list, H

# %%
topics, H = NMF_model(tweets_classified_US, noun_tweets, 30)
# Out:
# Topic  0
# report humans, humans trump, trump officials, humans trump officials, report humans trump, officials nytimes, trump officials nytimes, government report humans, trump officials york, officials york
#
# Topic  1
# trumptrain maga, trumplies trumptrain, trumplies trumptrain maga, goptaxscam jobs, trumptrain maga goptaxscam, maga goptaxscam, maga goptaxscam jobs, impeachtrump trumplies, impeachtrump trumplies trumptrain, votethemout trumplies
#
# Topic  2
# tax cut, trump tax, trump tax cut, company trump, company trump tax, ceo company, ceo company trump, patagonia ceo, patagonia ceo company, dollar company trump
#
# Topic  3
# banks rights, sign banks, sign banks rights, rights actcampaign, banks rights actcampaign, banks rights equatorbanksact, rights equatorbanksact, equatorbanksact actcampaign, rights equatorbanksact actcampaign, tell banks rights
#
# Topic  4
# administration explanation, trump administration explanation, explanation wapo, administration explanation wapo, administration explanation washington, explanation washington post, explanation washington, washington post, explanation science, explanation environment
#
# Topic  5
# city water, water air, nature science, today city, science today, nature science today, trump nature science, science today city, trump nature, today city water
#
# Topic  6
# sea level, level rise, sea level rise, rates sea level, rates sea, satellite data, data sea level, data sea, satellite data sea, years satellite data
#
# Topic  7
# risk time, animals risk time, pray bear animals, risk time argue, pray bear, bear animals risk, bear animals, time argue, animals risk, animals risk extinction
#
# Topic  8
# agency scientists, talk agency, talk agency scientists, agency scientists talks, scientists talks, agency scientists nytimes, scientists nytimes, talks huffpostpol, scientists talks huffpostpol, epa cancels
#
# Topic  9
# al gore, al gore predictions, gore predictions, gore predictions years, predictions years, al gore rips, gore rips, al gore bet, gore bet, gore trump
#
# Topic  10
# power plan, obama era, administration obama, administration obama era, era power, era power plan, obama era power, administrator pruitt, pruitt administration, pruitt administration obama
#
# Topic  11
# women girls, girls help, women girls help, support women, women world, help support, girls help support, help support women, support women world, world glblctzncan
#
# Topic  12
# sign petition, blackrock vanguard, fidelity power, vanguard fidelity power, vanguard fidelity, blackrock vanguard fidelity, demand blackrock vanguard, demand blackrock, petition demand, petition demand blackrock
#
# Topic  13
# protect animals click, animals click, protect animals, po st, click po, animals click po, click po st, site po st, site po, help bears
#
# Topic  14
# ice age, mini ice, mini ice age, years ice age, earth ice, years ice, ice age years, age years, earth ice age, end ice age
#
# Topic  15
# government report, humans government report, humans government, report trump, government report trump, report today, government report today, government report usatoday, report usatoday, government report humans
#
# Topic  16
# trump administration, administration report, trump administration report, youtube video, trump administration effort, administration effort, report trump administration, trump administration coal, administration coal, administration coal conference
#
# Topic  17
# oil companies, york city, sues oil, sues oil companies, city sues, york city sues, city sues oil, city oil, york city oil, city oil companies
#
# Topic  18
# hundreds billions, billions year, hundreds billions year, costs hundreds, costs hundreds billions, year geographic, billions year geographic, billions year natgeo, year natgeo, hidden costs
#
# Topic  19
# scott pruitt, pruitt thing, scott pruitt thing, epa scott, epa scott pruitt, washington post, pruitt humans, scott pruitt humans, thing washington, pruitt thing washington
#
# Topic  20
# psychologist people, people activists, ideas impact, activists ideas, activists ideas impact, psychologist people activists, people activists ideas, pron psychologist people, pron psychologist, people talk
#
# Topic  21
# teachers teach, teach parents, teachers teach parents, teach parents npr, parents npr, teach parents education, parents education, npr teachers teach, npr teachers, story npr teachers
#
# Topic  22
# realdonaldtrump epascottpruitt, emissions realdonaldtrump epascottpruitt, emissions realdonaldtrump, activities realdonaldtrump epascottpruitt, gas emissions realdonaldtrump, activities realdonaldtrump, gas realdonaldtrump epascottpruitt, gas realdonaldtrump, percent realdonaldtrump, percent realdonaldtrump epascottpruitt
#
# Topic  23
# energy innovation, innovation carbon, carbon dividend, energy innovation carbon, innovation carbon dividend, dividend act, carbon dividend act, thank energy, thank energy innovation, act leadership
#
# Topic  24
# auto alliance, trade group, auto alliance trade, alliance trade, alliance trade group, group climatescience, trade group climatescience, toyota auto, toyota auto alliance, ford toyota
#
# Topic  25
# world leaders, leaders trump, lone holdout, world leaders trump, trump lone, trump lone holdout, leaders trump lone, holdout motherjones, lone holdout motherjones, holdout mother
#
# Topic  26
# scientists conference, conference presentations, scientists conference presentations, yanks scientists, yanks scientists conference, washington post, presentations washington, conference presentations washington, presentations washington post, article day
#
# Topic  27
# greenhouse gas, gas emissions, greenhouse gas emissions, carbon dioxide, gas emissions realdonaldtrump, emissions realdonaldtrump epascottpruitt, emissions realdonaldtrump, freight train, speeding freight, speeding freight train
#
# Topic  28
# book ralphbalexander, ralphbalexander science, book ralphbalexander science, fb instagram, instagram twitter, fb instagram twitter, peace resist, resist science, peace resist science, twitter babyboomers
#
# Topic  29
# let pron, portfolio let pron, portfolio let, pron pron, pron let, pron let pron, let pron pron, air let pron, air let, earth day

# %%
# Replace the column names in H with the following topic titles (determined from the topics above)

topics_cleaned = ['full_text', 'Contradict Trump', 'Donald Trump Lies (Impeachment)', 'Patagonia CEO Donation',
                  'Equator Banks Act', 'Nov 2017 Scientific Report (Wash_Post)', 'Air and Water Quality',
                  'Sea Levels Rise', 'Animals at Risk', 'EPA Cancels CC Scientist Talks (NY_Times)',
                  'Al Gore', 'Obama Era Policies', 'Women Involvement', 'BlackRock_Petition',
                  'Animal Protection', 'Mini Ice Age', 'Human Impact on Earth', 'Coal Conference',  
                  'Oil Company Lawsuit', 'Cost of Climate Change', 'Scott Pruitt', 'Activism',                   
                  'Teach Climate Change', 'CO2 Emissions', 'Energy Innovation (Carbon Dividend)', 
                  'Auto Alliance', 'EPA Yanks CC Conference (Wash_Post)', 'Paris Agreement', 
                  'Greenhouse Gas Emissions', 'Ralph B Alexander', 'Earth Day']

# %% [markdown]
# ---

# %%
# topics_2019 = ['BlackRock_Petition', 'Teach Climate Change', 'Activism',
#                'Ralph B. Alexander', 'Earth Day', 'Liberal Politicians',
#                'Oil Industry Policies', 'CO2 Levels', 'Trump Admin Policies',
#                'NYC Hot Dog Ban', 'NYC Hot Dog Ban', 'Power Pros Cons',
#                'Congress Climate Priority', 'Sea Level Rise', 'NZ Planting Trees']

# %%
# topics_2017, H_17 = NMF_model(tweets_classified_US_2017, noun_tweets17, 15)

# %%
# topics_2018 = ['Donald Trump Lies', 'Clean Air and Water', 'Patagonia CEO Donation',
#                'Animals at Risk', 'Women Involvement', 'Al Gore',
#                'Sea Level Rise', 'EPA Scott Pruitt', 'Auto Alliance',
#                'Oil Company Lawsuit', 'Paris Agreement', 'Boomers Comics',
#                'Ice Age', 'Protect Animals', 'Energy Innovation (Carbon Dividend)']

# %%
# topics_2018, H_18 = NMF_model(tweets_classified_US_2018, noun_tweets18, 15)

# %%
# topics_2017 = ['Contradict Trump', 'Equator Banks Act', 'Nov 2017 Scientific Report (Wash_Post)',
#                'EPA Cancels CC Scientist Talks (Huff_Post)', 'Obama Power Plan', 'Costs of Climate Change',
#                'EPA Cancels CC Scientist Talks (Wash_Post)', 'Nov 2017 Scientific Report', 'Climate Change Taxpayer Cost', 'Trump Admin Policies (NYTimes)',
#                'Greenhouse Gas Emissions', 'Trump Skepticism', 'Nov 2017 Scientific Report (Wash_Post_#2)',
#                'Congress Climate Priority', 'Climate Change Taxpayer Cost (NBC News)', 'Hurricanes']

# %%
# topics_2019, H_19 = NMF_model(tweets_classified_US_2019, noun_tweets19, 15)

# %% [markdown]
# ---

# %% [markdown]
# ## Clean up `H` dataframe
# - Rename column names with topic titles
# - Add in the following features
#     - Believer_or_Denier
#     - Tweet_Sentiment (get dummies)
#     - User_Region (get dummies)

# %%
H.columns = topics_cleaned

# %%
H.insert(1, column = 'Believer_or_Denier', value = tweets_classified_US['Believer_or_Denier'])

# %%
H.insert(2, column = 'Tweet_Sentiment', value = tweets_classified_US['Tweet_Sentiment'])

# %%
with open('Data/tweets_classified_US_region.pkl','rb') as read_file:
    tweets_classified_US_region = pickle.load(read_file)

# %%
H.insert(3, column = 'User_Region', value = tweets_classified_US_region['User_Region']

# %%
H = pd.get_dummies(H, prefix = ['User_Region'], columns = ['User_Region'])
H = pd.get_dummies(H, prefix = ['Tweet_Sentiment'], columns = ['Tweet_Sentiment'])

# %%
H
# Out:
#                                                  full_text  \
# 0        All #Hurricane victims should sue #Trump, #Pru...
# 3        San Francisco sues oil companies over #climate...
# 6        Is the 2017 #hurricane season worse than usual...
# 9        Trudeau is transitioning to climate change dis...
# 17       These Vermont-based companies want to conquer ...
# ...                                                    ...
# 4225408  The latest YHWH HOLY SCRIPTURES! https://t.co/...
# 4225409              All 800 left. https://t.co/Dr5aROHJzb
# 4225410  Look at this clever animation, showing the tem...
# 4225411  Climate Change: Why The Australian Labor Party...
# 4225414  Some of you are going to say climate change bu...
#
#                     User_Name  Believer_or_Denier  Contradict Trump  \
# 0               Soledad Haren             0.00000           0.00000
# 3                   A&R Solar             1.00000           0.00000
# 6        YouthBuild USA Green             0.00000           0.00000
# 9               brad schaible             0.00000           0.00000
# 17                 Seven Days             0.00000           0.00000
# ...                       ...                 ...               ...
# 4225408           CarrieGaard             0.00000           0.00000
# 4225409            Simarilian             0.00000           0.00000
# 4225410      Claudio Alatorre             0.00000           0.00000
# 4225411     Iowa Climate ����             0.00000           0.00000
# 4225414            whiteflags             0.00000           0.00000
#
#          Donald Trump Lies (Impeachment)  Patagonia CEO Donation  \
# 0                                0.00003                 0.00000
# 3                                0.00000                 0.00000
# 6                                0.00000                 0.00000
# 9                                0.00000                 0.00000
# 17                               0.00000                 0.00000
# ...                                  ...                     ...
# 4225408                          0.00000                 0.00000
# 4225409                          0.00000                 0.00000
# 4225410                          0.00000                 0.00000
# 4225411                          0.00000                 0.00000
# 4225414                          0.00000                 0.00000
#
#          Equator Banks Act  Nov 2017 Scientific Report (Wash_Post)  \
# 0                  0.00000                                 0.00000
# 3                  0.00000                                 0.00000
# 6                  0.00000                                 0.00000
# 9                  0.00000                                 0.00000
# 17                 0.00000                                 0.00000
# ...                    ...                                     ...
# 4225408            0.00000                                 0.00000
# 4225409            0.00000                                 0.00000
# 4225410            0.00000                                 0.00000
# 4225411            0.00000                                 0.00000
# 4225414            0.00000                                 0.00000
#
#          Air and Water Quality  Sea Levels Rise  Animals at Risk  \
# 0                      0.00000          0.00003          0.00000
# 3                      0.00000          0.00000          0.00000
# 6                      0.00000          0.00000          0.00000
# 9                      0.00000          0.00000          0.00000
# 17                     0.00001          0.00000          0.00000
# ...                        ...              ...              ...
# 4225408                0.00000          0.00000          0.00000
# 4225409                0.00000          0.00000          0.00000
# 4225410                0.00000          0.00000          0.00000
# 4225411                0.00000          0.00000          0.00000
# 4225414                0.00000          0.00000          0.00000
#
#          EPA Cancels CC Scientist Talks (NY_Times)  Al Gore  \
# 0                                          0.00002  0.00000
# 3                                          0.00000  0.00000
# 6                                          0.00000  0.00002
# 9                                          0.00000  0.00000
# 17                                         0.00000  0.00000
# ...                                            ...      ...
# 4225408                                    0.00000  0.00000
# 4225409                                    0.00000  0.00000
# 4225410                                    0.00000  0.00000
# 4225411                                    0.00000  0.00000
# 4225414                                    0.00000  0.00000
#
#          Obama Era Policies  Women Involvement  BlackRock_Petition  \
# 0                   0.00001            0.00000             0.00000
# 3                   0.00000            0.00000             0.00000
# 6                   0.00000            0.00000             0.00000
# 9                   0.00000            0.00000             0.00000
# 17                  0.00000            0.00000             0.00000
# ...                     ...                ...                 ...
# 4225408             0.00000            0.00000             0.00000
# 4225409             0.00000            0.00000             0.00000
# 4225410             0.00000            0.00000             0.00000
# 4225411             0.00000            0.00000             0.00000
# 4225414             0.00000            0.00000             0.00000
#
#          Animal Protection  Mini Ice Age  Human Impact on Earth  \
# 0                  0.00000       0.00000                0.00002
# 3                  0.00004       0.00000                0.00000
# 6                  0.00000       0.00000                0.00000
# 9                  0.00000       0.00000                0.00000
# 17                 0.00000       0.00000                0.00000
# ...                    ...           ...                    ...
# 4225408            0.00000       0.00000                0.00000
# 4225409            0.00000       0.00000                0.00000
# 4225410            0.00000       0.00000                0.00000
# 4225411            0.00000       0.00000                0.00000
# 4225414            0.00000       0.00000                0.00000
#
#          Coal Conference  Oil Company Lawsuit  Cost of Climate Change  \
# 0                0.00001              0.00204                 0.00000
# 3                0.00000              0.10203                 0.00000
# 6                0.00000              0.00000                 0.00000
# 9                0.00000              0.00000                 0.00000
# 17               0.00000              0.00008                 0.00000
# ...                  ...                  ...                     ...
# 4225408          0.00000              0.00000                 0.00000
# 4225409          0.00000              0.00000                 0.00000
# 4225410          0.00000              0.00000                 0.00000
# 4225411          0.00000              0.00001                 0.00000
# 4225414          0.00000              0.00000                 0.00000
#
#          Scott Pruitt  Activism  Teach Climate Change  CO2 Emissions  \
# 0             0.00002   0.00000               0.00000        0.00002
# 3             0.00000   0.00000               0.00000        0.00000
# 6             0.00008   0.00000               0.00000        0.00000
# 9             0.00000   0.00000               0.00000        0.00000
# 17            0.00000   0.00000               0.00000        0.00000
# ...               ...       ...                   ...            ...
# 4225408       0.00000   0.00000               0.00000        0.00000
# 4225409       0.00000   0.00000               0.00000        0.00000
# 4225410       0.00000   0.00000               0.00000        0.00000
# 4225411       0.00000   0.00000               0.00000        0.00000
# 4225414       0.00000   0.00000               0.00000        0.00000
#
#          Energy Innovation (Carbon Dividend)  Auto Alliance  \
# 0                                    0.00000        0.00000
# 3                                    0.00000        0.00000
# 6                                    0.00000        0.00000
# 9                                    0.00000        0.00000
# 17                                   0.00000        0.00000
# ...                                      ...            ...
# 4225408                              0.00000        0.00000
# 4225409                              0.00000        0.00000
# 4225410                              0.00000        0.00000
# 4225411                              0.00000        0.00000
# 4225414                              0.00000        0.00000
#
#          EPA Yanks CC Conference (Wash_Post)  Paris Agreement  \
# 0                                    0.00000          0.00000
# 3                                    0.00000          0.00000
# 6                                    0.00000          0.00000
# 9                                    0.00000          0.00000
# 17                                   0.00000          0.00000
# ...                                      ...              ...
# 4225408                              0.00000          0.00000
# 4225409                              0.00000          0.00000
# 4225410                              0.00000          0.00000
# 4225411                              0.00000          0.00000
# 4225414                              0.00000          0.00000
#
#          Greenhouse Gas Emissions  Ralph B Alexander  Earth Day  \
# 0                         0.00001            0.00000    0.00000
# 3                         0.00000            0.00000    0.00000
# 6                         0.00000            0.00000    0.00001
# 9                         0.00000            0.00000    0.00000
# 17                        0.00000            0.00000    0.00000
# ...                           ...                ...        ...
# 4225408                   0.00000            0.00000    0.00000
# 4225409                   0.00000            0.00000    0.00000
# 4225410                   0.00000            0.00000    0.00000
# 4225411                   0.00000            0.00000    0.00004
# 4225414                   0.00000            0.00000    0.00000
#
#          User_Region_Alaska  User_Region_Hawaii  User_Region_Midwest  \
# 0                         0                   0                    0
# 3                         0                   0                    0
# 6                         0                   0                    0
# 9                         0                   0                    0
# 17                        0                   0                    0
# ...                     ...                 ...                  ...
# 4225408                   0                   0                    0
# 4225409                   0                   0                    0
# 4225410                   0                   0                    0
# 4225411                   0                   0                    1
# 4225414                   0                   0                    1
#
#          User_Region_Northeast  User_Region_Rockies  User_Region_South  \
# 0                            1                    0                  0
# 3                            0                    0                  0
# 6                            1                    0                  0
# 9                            0                    0                  1
# 17                           1                    0                  0
# ...                        ...                  ...                ...
# 4225408                      0                    0                  1
# 4225409                      0                    0                  0
# 4225410                      1                    0                  0
# 4225411                      0                    0                  0
# 4225414                      0                    0                  0
#
#          User_Region_Southwest  User_Region_US  User_Region_West Coast  \
# 0                            0               0                       0
# 3                            0               0                       1
# 6                            0               0                       0
# 9                            0               0                       0
# 17                           0               0                       0
# ...                        ...             ...                     ...
# 4225408                      0               0                       0
# 4225409                      0               0                       1
# 4225410                      0               0                       0
# 4225411                      0               0                       0
# 4225414                      0               0                       0
#
#          Tweet_Sentiment_negative  Tweet_Sentiment_neutral  \
# 0                               0                        1
# 3                               0                        1
# 6                               1                        0
# 9                               0                        0
# 17                              0                        1
# ...                           ...                      ...
# 4225408                         0                        0
# 4225409                         0                        1
# 4225410                         0                        0
# 4225411                         0                        0
# 4225414                         0                        1
#
#          Tweet_Sentiment_positive
# 0                               0
# 3                               0
# 6                               0
# 9                               1
# 17                              0
# ...                           ...
# 4225408                         1
# 4225409                         0
# 4225410                         1
# 4225411                         1
# 4225414                         0
#
# [1235350 rows x 45 columns]

# %%
# with open('Data/cluster_df.pkl', 'wb') as to_write:
#     pickle.dump(H, to_write)

# %%
with open('Data/cluster_df.pkl','rb') as read_file:
    cluster_df = pickle.load(read_file)

# %%
del cluster_df['full_text']
del cluster_df['User_Name']

# %% [markdown]
# # PCA

# %% [markdown]
# - Dimensionality reduction will be performed with PCA
# - A scree plot will be used to determine the ideal number of components
#     - The following question needs to be answered:
#         - How many components are needed to explain at least 80% of the variance of the dataset?

# %%
from sklearn import datasets
from sklearn.decomposition import PCA

# %%
std = StandardScaler()

std.fit(cluster_df.values)
cluster_scaled = std.transform(cluster_df.values)

# %%
cluster_array = cluster_df.to_numpy()

# %%
def pca_function(array, n_components, random_state):
    
    pca = PCA(n_components=n_components, random_state=random_state)
    pca.fit(array)
    pca_features = pca.transform(array)
    
    return pca, pca_features

# %%
pca40, pca40_features = pca_function(cluster_scaled, 40, 42)

# %% [markdown]
# ## Scree Plot and Cumulative Explained Variance Plot

# %% [markdown]
# - It's important to explain at least 80% of the variance. This occurs at around 30 principal components.
# - Moving past 30, there is a noticeable elbow at 39 components.
# - It appears that the variance is almost completely explained at this point, so 39 components will be used.

# %%
plt.plot(pca40.explained_variance_ratio_)
plt.xlabel('# components')
plt.ylabel('explained variance');
plt.title('Scree Plot');

# %%
plt.plot(np.cumsum(pca40.explained_variance_ratio_))
plt.xlabel('# components')
plt.ylabel('cumulative explained variance');
plt.title('Cumulative explained variance by PCA')
# Out:
# Text(0.5, 1.0, 'Cumulative explained variance by PCA')

# %% [markdown]
# ## Create `pca_df`

# %%
pca39, pca39_features = pca_function(cluster_array, 39, 42)

# %%
pca_index = ['PC' + str(i) for i in range(1,40)]

# %%
pca_df = pd.DataFrame(pca39.components_, columns = cluster_df.columns, index = pca_index)

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
pca_df
# Out:
#       Believer_or_Denier  Contradict Trump  Donald Trump Lies (Impeachment)  \
# PC1              0.01521          -0.00022                          0.00004
# PC2              0.09679          -0.00006                         -0.00043
# PC3              0.03527          -0.00010                          0.00016
# PC4              0.08974          -0.00002                         -0.00001
# PC5              0.07517          -0.00003                         -0.00011
# PC6              0.36831          -0.00004                         -0.00005
# PC7              0.91612          -0.00011                         -0.00003
# PC8              0.02230          -0.00005                         -0.00008
# PC9             -0.00293          -0.00000                         -0.00007
# PC10             0.00194          -0.00002                         -0.00009
# PC11            -0.00010           0.00008                         -0.00003
# PC12             0.00013           0.99788                         -0.04740
# PC13             0.00005           0.04250                          0.97777
# PC14             0.00006           0.01593                          0.09093
# PC15             0.00018           0.02042                          0.17763
# PC16             0.00004           0.01067                          0.02010
# PC17             0.00016           0.00098                          0.01090
# PC18             0.00020           0.01874                         -0.00206
# PC19             0.00018           0.01647                          0.01887
# PC20             0.00014           0.00361                          0.02467
# PC21             0.00019           0.00275                          0.01316
# PC22            -0.00135           0.00196                          0.00325
# PC23             0.00004           0.00141                          0.00250
# PC24             0.00018          -0.00225                          0.00755
# PC25             0.00014           0.00103                          0.00620
# PC26             0.00011           0.00098                          0.00401
# PC27             0.00012           0.00473                          0.00482
# PC28            -0.00073           0.00087                          0.00137
# PC29            -0.00005           0.00722                         -0.00000
# PC30            -0.00076           0.00584                          0.00607
# PC31             0.00005           0.00087                          0.00184
# PC32             0.00003           0.00237                          0.00196
# PC33             0.00004           0.00669                          0.00082
# PC34             0.00010          -0.02859                          0.00172
# PC35             0.00011           0.00156                          0.00173
# PC36             0.00011           0.00232                          0.00198
# PC37             0.00006           0.00150                          0.00279
# PC38             0.00014           0.00090                          0.00184
# PC39             0.00012           0.00255                          0.00214
#
#       Patagonia CEO Donation  Equator Banks Act  \
# PC1                  0.00018            0.00022
# PC2                 -0.00007           -0.00007
# PC3                 -0.00014           -0.00015
# PC4                 -0.00004           -0.00005
# PC5                 -0.00003           -0.00003
# PC6                 -0.00007           -0.00010
# PC7                 -0.00009           -0.00008
# PC8                  0.00000           -0.00001
# PC9                  0.00001            0.00004
# PC10                 0.00002            0.00007
# PC11                -0.00004           -0.00000
# PC12                -0.01668           -0.00586
# PC13                -0.16494           -0.11691
# PC14                 0.87842           -0.46852
# PC15                 0.44679            0.87491
# PC16                 0.02108            0.02270
# PC17                 0.00569            0.00500
# PC18                 0.00253           -0.00237
# PC19                 0.01676            0.01526
# PC20                 0.00265            0.00128
# PC21                 0.01288            0.01353
# PC22                 0.00232            0.00320
# PC23                 0.00817            0.00927
# PC24                 0.01161            0.01164
# PC25                 0.00098            0.00057
# PC26                 0.00579            0.00629
# PC27                 0.00122            0.00050
# PC28                 0.00184            0.00151
# PC29                -0.00049           -0.00134
# PC30                 0.00348            0.00287
# PC31                 0.00370            0.00404
# PC32                 0.00033           -0.00002
# PC33                 0.00203            0.00137
# PC34                 0.00436            0.00445
# PC35                 0.00049            0.00029
# PC36                 0.00240            0.00229
# PC37                 0.00219            0.00200
# PC38                 0.00389            0.00374
# PC39                 0.00174            0.00149
#
#       Nov 2017 Scientific Report (Wash_Post)  Air and Water Quality  \
# PC1                                  0.00004               -0.00019
# PC2                                  0.00016                0.00006
# PC3                                  0.00037               -0.00013
# PC4                                 -0.00004                0.00002
# PC5                                 -0.00002                0.00035
# PC6                                 -0.00008                0.00077
# PC7                                 -0.00017               -0.00055
# PC8                                  0.00000               -0.00030
# PC9                                  0.00005               -0.00018
# PC10                                 0.00001               -0.00019
# PC11                                 0.00002               -0.00011
# PC12                                -0.00118               -0.01952
# PC13                                -0.00990                0.00113
# PC14                                -0.00321               -0.00376
# PC15                                -0.00617                0.00028
# PC16                                -0.11008               -0.04098
# PC17                                 0.98611               -0.04024
# PC18                                 0.03285                0.99473
# PC19                                 0.05391                0.07874
# PC20                                 0.06976               -0.00896
# PC21                                 0.01713                0.00589
# PC22                                 0.00271                0.00104
# PC23                                 0.00689               -0.00393
# PC24                                -0.07582                0.01732
# PC25                                 0.01265               -0.00032
# PC26                                -0.00001                0.00021
# PC27                                -0.00092                0.00720
# PC28                                -0.00035                0.00389
# PC29                                 0.01094                0.00479
# PC30                                 0.00195                0.00541
# PC31                                -0.00004               -0.00010
# PC32                                 0.00016                0.00294
# PC33                                 0.00023                0.00549
# PC34                                 0.00455                0.00276
# PC35                                 0.00611                0.00103
# PC36                                 0.00077                0.00205
# PC37                                 0.00433                0.00241
# PC38                                 0.00211                0.00089
# PC39                                 0.00199                0.00263
#
#       Sea Levels Rise  Animals at Risk  \
# PC1          -0.00000          0.00003
# PC2          -0.00002         -0.00011
# PC3           0.00003          0.00047
# PC4          -0.00000         -0.00004
# PC5          -0.00010         -0.00008
# PC6          -0.00003         -0.00007
# PC7          -0.00014         -0.00010
# PC8           0.00003         -0.00005
# PC9          -0.00005         -0.00004
# PC10          0.00015         -0.00003
# PC11         -0.00018         -0.00003
# PC12         -0.01334         -0.00098
# PC13         -0.01650         -0.02184
# PC14         -0.00954         -0.00308
# PC15         -0.02507         -0.00435
# PC16         -0.03557         -0.00789
# PC17         -0.06107         -0.06577
# PC18         -0.08237          0.01362
# PC19          0.98686         -0.10412
# PC20          0.09783          0.99093
# PC21          0.04141          0.03668
# PC22          0.01758         -0.00353
# PC23          0.00871         -0.00608
# PC24          0.03191          0.01471
# PC25          0.00914          0.02016
# PC26          0.00671          0.00079
# PC27          0.00746          0.00349
# PC28          0.00571          0.00199
# PC29          0.00483         -0.00263
# PC30         -0.00845          0.00370
# PC31          0.00309         -0.00014
# PC32          0.00208          0.00110
# PC33          0.00595         -0.00161
# PC34          0.00548          0.00156
# PC35          0.00332          0.00674
# PC36          0.00360          0.00040
# PC37          0.00439          0.00553
# PC38          0.00478          0.00114
# PC39          0.00087          0.00253
#
#       EPA Cancels CC Scientist Talks (NY_Times)  Al Gore  Obama Era Policies  \
# PC1                                     0.00017  0.00006            -0.00016
# PC2                                    -0.00007  0.00012             0.00007
# PC3                                    -0.00004 -0.00001            -0.00011
# PC4                                    -0.00003  0.00018             0.00026
# PC5                                    -0.00003  0.00009            -0.00017
# PC6                                    -0.00005  0.00051            -0.00009
# PC7                                    -0.00012  0.00129            -0.00011
# PC8                                    -0.00004  0.00002            -0.00007
# PC9                                     0.00001 -0.00002            -0.00006
# PC10                                   -0.00001  0.00000            -0.00007
# PC11                                    0.00002 -0.00002            -0.00006
# PC12                                   -0.00074 -0.00149            -0.00506
# PC13                                   -0.00764 -0.00229            -0.00106
# PC14                                   -0.00585 -0.00087            -0.00125
# PC15                                   -0.01947 -0.00447            -0.00201
# PC16                                   -0.01667 -0.00905            -0.00539
# PC17                                   -0.01160 -0.00027             0.00789
# PC18                                   -0.00472 -0.00066            -0.00714
# PC19                                   -0.04212 -0.01859            -0.01093
# PC20                                   -0.04279  0.00199            -0.00119
# PC21                                    0.99578 -0.02814            -0.00726
# PC22                                    0.02425  0.99702            -0.00954
# PC23                                    0.04135  0.03151            -0.00961
# PC24                                    0.03610  0.03277             0.23783
# PC25                                    0.00591 -0.00142             0.01083
# PC26                                    0.01057  0.00269             0.01652
# PC27                                    0.00273  0.00001            -0.04250
# PC28                                    0.00320  0.02535            -0.18525
# PC29                                   -0.00123  0.00526             0.95101
# PC30                                    0.00553  0.04356             0.02515
# PC31                                    0.00546  0.00264            -0.00316
# PC32                                    0.00105  0.00167             0.01202
# PC33                                    0.00089  0.00368             0.01715
# PC34                                    0.00620  0.00370             0.02446
# PC35                                    0.00179 -0.00022            -0.00070
# PC36                                    0.00309  0.00142             0.00517
# PC37                                    0.00008  0.00381            -0.01559
# PC38                                    0.00389  0.00191            -0.00167
# PC39                                    0.00210  0.00071             0.00232
#
#       Women Involvement  BlackRock_Petition  Animal Protection  Mini Ice Age  \
# PC1             0.00002             0.00015           -0.00015      -0.00002
# PC2             0.00002            -0.00006           -0.00010       0.00013
# PC3             0.00033            -0.00010           -0.00003       0.00001
# PC4            -0.00003            -0.00000            0.00009       0.00013
# PC5            -0.00004            -0.00000           -0.00005       0.00007
# PC6            -0.00006            -0.00006            0.00001       0.00032
# PC7            -0.00011            -0.00007           -0.00008       0.00071
# PC8            -0.00003            -0.00003           -0.00008       0.00003
# PC9             0.00002            -0.00002           -0.00004       0.00001
# PC10           -0.00000            -0.00003           -0.00007      -0.00001
# PC11           -0.00007            -0.00006           -0.00004       0.00002
# PC12           -0.00064            -0.00054           -0.00471      -0.00254
# PC13           -0.00518            -0.00218           -0.00428      -0.00127
# PC14           -0.00093            -0.00236           -0.00107      -0.00119
# PC15           -0.00142            -0.00821           -0.00097      -0.00224
# PC16           -0.00169            -0.00490           -0.00268       0.00114
# PC17           -0.01242            -0.00120           -0.00051      -0.00242
# PC18            0.00023            -0.00017           -0.00708      -0.00490
# PC19           -0.00747            -0.00642           -0.00714      -0.00438
# PC20           -0.02181            -0.00121           -0.00352      -0.00211
# PC21           -0.00713            -0.01037           -0.00217      -0.00242
# PC22            0.00093            -0.00325           -0.00114      -0.03156
# PC23            0.00081            -0.01088            0.00234      -0.00298
# PC24           -0.01751            -0.01885           -0.02006      -0.01574
# PC25            0.99907            -0.01025           -0.01777      -0.01080
# PC26            0.00844             0.99785           -0.05212      -0.01504
# PC27            0.01756             0.05139            0.99637      -0.02826
# PC28            0.01081             0.01579            0.01420       0.97034
# PC29           -0.00453            -0.00806            0.05227       0.18739
# PC30            0.00883             0.01239            0.01972       0.14262
# PC31            0.00058             0.01275           -0.00070       0.00624
# PC32            0.00178             0.00089            0.00910       0.00781
# PC33           -0.00012             0.00267            0.01315       0.01731
# PC34            0.00309             0.00996            0.00378       0.00641
# PC35            0.01030             0.00069            0.00081       0.00347
# PC36            0.00120             0.00393            0.00375       0.00324
# PC37            0.00746             0.00224            0.00270       0.00625
# PC38            0.00223             0.00549            0.00070       0.00411
# PC39            0.00261             0.00192            0.00335       0.00111
#
#       Human Impact on Earth  Coal Conference  Oil Company Lawsuit  \
# PC1                 0.00011          0.00000             -0.00008
# PC2                -0.00005         -0.00003             -0.00001
# PC3                -0.00009         -0.00003             -0.00003
# PC4                 0.00001         -0.00002             -0.00000
# PC5                -0.00001          0.00001              0.00001
# PC6                -0.00003         -0.00006              0.00025
# PC7                -0.00012         -0.00016              0.00055
# PC8                -0.00004         -0.00006              0.00001
# PC9                 0.00005         -0.00001             -0.00003
# PC10               -0.00003          0.00010             -0.00002
# PC11               -0.00003         -0.00000             -0.00002
# PC12                0.02958          0.00232             -0.00483
# PC13                0.00093         -0.00366             -0.00481
# PC14               -0.00159         -0.00459             -0.00215
# PC15               -0.00616         -0.01424             -0.00473
# PC16               -0.00471         -0.01976             -0.00510
# PC17                0.00295          0.07782             -0.00330
# PC18               -0.00281         -0.01179             -0.00587
# PC19               -0.00711         -0.02394              0.00947
# PC20               -0.00293         -0.01202             -0.00243
# PC21               -0.00906         -0.03351             -0.00359
# PC22               -0.00565         -0.03197             -0.03906
# PC23               -0.00967         -0.05389             -0.00306
# PC24                0.08343          0.96000             -0.01541
# PC25               -0.00148          0.01490             -0.00757
# PC26               -0.00879          0.01317             -0.01088
# PC27                0.00021          0.03104             -0.01713
# PC28                0.00593          0.05826             -0.13877
# PC29               -0.04467         -0.22822             -0.05201
# PC30               -0.01688          0.01103              0.98428
# PC31               -0.01830          0.01007              0.02053
# PC32               -0.00523          0.00343              0.02378
# PC33               -0.01363          0.01208              0.07203
# PC34                0.99355         -0.09214              0.01770
# PC35               -0.03557          0.00680              0.00402
# PC36                0.01660          0.00532              0.00847
# PC37                0.00355         -0.00170              0.00808
# PC38                0.01297          0.00286              0.00360
# PC39                0.00243         -0.00161             -0.00817
#
#       Cost of Climate Change  Scott Pruitt  Activism  Teach Climate Change  \
# PC1                  0.00003       0.00004  -0.00017              -0.00013
# PC2                  0.00011       0.00006   0.00012              -0.00002
# PC3                  0.00024       0.00015  -0.00016              -0.00006
# PC4                 -0.00003      -0.00003  -0.00035               0.00002
# PC5                 -0.00003      -0.00001  -0.00021               0.00000
# PC6                 -0.00003      -0.00002  -0.00006              -0.00006
# PC7                 -0.00014      -0.00009  -0.00001              -0.00006
# PC8                  0.00003      -0.00002  -0.00009              -0.00002
# PC9                 -0.00001      -0.00002  -0.00007               0.00002
# PC10                -0.00005       0.00004  -0.00008              -0.00005
# PC11                -0.00002      -0.00007  -0.00005              -0.00006
# PC12                -0.00035      -0.00127  -0.00466              -0.00345
# PC13                -0.00127      -0.00175   0.00056              -0.00159
# PC14                -0.00043      -0.00123  -0.00075              -0.00065
# PC15                -0.00080      -0.00325  -0.00123              -0.00068
# PC16                -0.00082      -0.00192  -0.00194              -0.00165
# PC17                -0.00591      -0.00356  -0.00080              -0.00052
# PC18                -0.00118      -0.00232  -0.00345              -0.00383
# PC19                -0.00326      -0.00470  -0.00572              -0.00426
# PC20                -0.00739      -0.00606   0.00156              -0.00071
# PC21                -0.00243      -0.00105   0.00007              -0.00091
# PC22                 0.00025      -0.00365   0.00010              -0.00033
# PC23                -0.00012      -0.00244   0.00227              -0.00062
# PC24                -0.00284       0.00496  -0.01058              -0.00923
# PC25                -0.01085      -0.00718   0.00107              -0.00137
# PC26                -0.00122      -0.00217  -0.00078              -0.00080
# PC27                -0.00126      -0.00318  -0.00822              -0.01142
# PC28                -0.00354      -0.00837  -0.00347              -0.00383
# PC29                 0.00049       0.01411  -0.01027              -0.01567
# PC30                -0.00531      -0.00810  -0.06188              -0.04761
# PC31                -0.00198      -0.00440  -0.05469              -0.01398
# PC32                -0.00111      -0.00188  -0.31800               0.94758
# PC33                -0.00379      -0.00662   0.94414               0.31457
# PC34                 0.03540      -0.00572   0.00961               0.00823
# PC35                 0.99883      -0.02514   0.00216               0.00139
# PC36                 0.00685      -0.03643   0.01091               0.00682
# PC37                 0.02389       0.98735   0.00545               0.00353
# PC38                 0.01252       0.13638   0.00097               0.00293
# PC39                 0.00331       0.00570   0.00492               0.00363
#
#       CO2 Emissions  Energy Innovation (Carbon Dividend)  Auto Alliance  \
# PC1         0.00011                             -0.00002        0.00013
# PC2         0.00001                             -0.00000       -0.00002
# PC3        -0.00008                             -0.00009       -0.00010
# PC4        -0.00000                             -0.00004       -0.00003
# PC5         0.00009                              0.00001       -0.00000
# PC6         0.00001                             -0.00013       -0.00006
# PC7        -0.00017                             -0.00007       -0.00005
# PC8         0.00157                              0.00010        0.00001
# PC9        -0.00044                             -0.00010        0.00004
# PC10       -0.00030                             -0.00009       -0.00004
# PC11       -0.00013                             -0.00009        0.00005
# PC12       -0.00025                             -0.00246       -0.00035
# PC13        0.00012                             -0.00121       -0.00046
# PC14       -0.00124                             -0.00115       -0.00143
# PC15       -0.00372                             -0.00319       -0.00514
# PC16       -0.00263                             -0.00141       -0.00140
# PC17       -0.00137                             -0.00121       -0.00063
# PC18        0.00026                             -0.00167        0.00021
# PC19       -0.00366                             -0.00367       -0.00343
# PC20       -0.00016                             -0.00079        0.00011
# PC21       -0.00316                             -0.00289       -0.00511
# PC22       -0.00089                             -0.00090       -0.00148
# PC23       -0.00173                             -0.00288       -0.00516
# PC24       -0.00400                             -0.00761       -0.00830
# PC25       -0.00059                             -0.00142       -0.00049
# PC26       -0.00450                             -0.00395       -0.01306
# PC27        0.00016                             -0.00371       -0.00059
# PC28       -0.00264                             -0.00196       -0.00493
# PC29        0.00098                             -0.00261        0.00379
# PC30       -0.00362                             -0.00821       -0.02598
# PC31       -0.00675                             -0.00537        0.99776
# PC32       -0.00179                             -0.00341       -0.00487
# PC33       -0.00003                             -0.01375        0.05404
# PC34       -0.01138                             -0.01764        0.01909
# PC35       -0.00784                             -0.00771        0.00103
# PC36       -0.04015                              0.99813        0.00556
# PC37       -0.13536                              0.03027        0.00377
# PC38        0.97459                              0.04451        0.00793
# PC39       -0.17276                             -0.00196        0.00185
#
#       EPA Yanks CC Conference (Wash_Post)  Paris Agreement  \
# PC1                               0.00009          0.00011
# PC2                              -0.00001         -0.00005
# PC3                              -0.00005         -0.00005
# PC4                              -0.00001          0.00000
# PC5                              -0.00000         -0.00000
# PC6                              -0.00002         -0.00003
# PC7                              -0.00008         -0.00009
# PC8                              -0.00001         -0.00003
# PC9                               0.00001         -0.00000
# PC10                             -0.00004          0.00007
# PC11                              0.00001         -0.00005
# PC12                             -0.00080         -0.00018
# PC13                              0.00135         -0.00105
# PC14                             -0.00061         -0.00086
# PC15                             -0.00226         -0.00274
# PC16                             -0.00116         -0.00141
# PC17                             -0.00083          0.00023
# PC18                             -0.00104         -0.00075
# PC19                             -0.00217         -0.00209
# PC20                             -0.00090         -0.00123
# PC21                             -0.00228          0.00271
# PC22                             -0.00048         -0.00069
# PC23                             -0.00172         -0.00166
# PC24                             -0.00113          0.00332
# PC25                             -0.00090         -0.00093
# PC26                             -0.00223         -0.00202
# PC27                             -0.00084         -0.00066
# PC28                             -0.00110         -0.00064
# PC29                             -0.00097         -0.00098
# PC30                             -0.00232         -0.00055
# PC31                             -0.00233         -0.00201
# PC32                             -0.00054         -0.00046
# PC33                             -0.00196         -0.00097
# PC34                             -0.00178         -0.00188
# PC35                             -0.00164         -0.00220
# PC36                             -0.00303         -0.00391
# PC37                             -0.00302          0.06200
# PC38                             -0.00498          0.00561
# PC39                              0.00572         -0.00011
#
#       Greenhouse Gas Emissions  Ralph B Alexander  Earth Day  \
# PC1                   -0.00005            0.00014    0.00006
# PC2                   -0.00006           -0.00000   -0.00003
# PC3                    0.00000           -0.00011   -0.00004
# PC4                   -0.00005            0.00000    0.00002
# PC5                   -0.00000            0.00039   -0.00003
# PC6                   -0.00005           -0.00034   -0.00005
# PC7                   -0.00011            0.00002   -0.00004
# PC8                    0.00014           -0.00014    0.00002
# PC9                   -0.00003           -0.00009   -0.00005
# PC10                  -0.00004           -0.00010   -0.00005
# PC11                  -0.00002           -0.00004   -0.00000
# PC12                  -0.00243           -0.00055   -0.01065
# PC13                  -0.00162            0.00030   -0.01621
# PC14                  -0.00122           -0.00298   -0.01113
# PC15                  -0.00303           -0.01178   -0.03588
# PC16                  -0.00138           -0.00877    0.99118
# PC17                  -0.00188           -0.00315    0.10599
# PC18                  -0.00269            0.00356    0.04136
# PC19                  -0.00140           -0.00925    0.04096
# PC20                  -0.00268            0.00540    0.01715
# PC21                  -0.00285           -0.04322    0.01829
# PC22                  -0.00120           -0.03500    0.00903
# PC23                  -0.00178            0.99679    0.00897
# PC24                   0.00002            0.05224    0.01481
# PC25                  -0.00276           -0.00039    0.00369
# PC26                  -0.00268            0.01087    0.00522
# PC27                  -0.00343           -0.00086    0.00360
# PC28                  -0.00225            0.00299   -0.00103
# PC29                  -0.00315           -0.00360    0.00152
# PC30                   0.00774            0.00251    0.00539
# PC31                  -0.00253            0.00536    0.00154
# PC32                  -0.00209            0.00147    0.00138
# PC33                  -0.00546           -0.00105    0.00340
# PC34                  -0.00478            0.00454    0.00426
# PC35                  -0.00457           -0.00008    0.00160
# PC36                  -0.00499            0.00301    0.00179
# PC37                  -0.02951            0.00195    0.00232
# PC38                   0.17016            0.00247    0.00368
# PC39                   0.98483            0.00127    0.00121
#
#       User_Region_Alaska  User_Region_Hawaii  User_Region_Midwest  \
# PC1             -0.00027             0.00048              0.00534
# PC2              0.00144             0.00148              0.10433
# PC3             -0.00069            -0.00194             -0.04373
# PC4              0.00013             0.00015              0.01338
# PC5              0.00240             0.00334              0.67735
# PC6              0.00103             0.00107             -0.53845
# PC7             -0.00126            -0.00288              0.15549
# PC8              0.00730             0.01041             -0.22562
# PC9              0.01675             0.02490             -0.14980
# PC10             0.23041             0.87764             -0.15256
# PC11             0.91403            -0.34335             -0.07972
# PC12            -0.00008             0.00004              0.00000
# PC13             0.00004             0.00008              0.00006
# PC14             0.00004             0.00001              0.00000
# PC15             0.00000            -0.00005              0.00001
# PC16             0.00001             0.00005             -0.00002
# PC17            -0.00004             0.00000             -0.00001
# PC18             0.00013             0.00015              0.00011
# PC19             0.00013            -0.00018              0.00010
# PC20             0.00005             0.00000              0.00005
# PC21            -0.00002             0.00001              0.00004
# PC22             0.00002            -0.00001              0.00001
# PC23             0.00006             0.00008             -0.00052
# PC24             0.00001            -0.00007             -0.00002
# PC25             0.00006            -0.00003              0.00001
# PC26             0.00006             0.00000             -0.00005
# PC27             0.00005             0.00004              0.00002
# PC28            -0.00003            -0.00000             -0.00000
# PC29             0.00007             0.00006              0.00003
# PC30             0.00002             0.00001              0.00004
# PC31            -0.00005             0.00004             -0.00002
# PC32             0.00005             0.00000             -0.00005
# PC33             0.00008             0.00007              0.00004
# PC34             0.00004             0.00002              0.00000
# PC35             0.00003             0.00003              0.00002
# PC36             0.00009             0.00005             -0.00009
# PC37             0.00004            -0.00009             -0.00003
# PC38             0.00020             0.00021              0.00019
# PC39            -0.00000            -0.00001             -0.00002
#
#       User_Region_Northeast  User_Region_Rockies  User_Region_South  \
# PC1                -0.04021              0.00280            0.02606
# PC2                -0.79248              0.02593            0.28547
# PC3                 0.37909             -0.01457           -0.11144
# PC4                -0.01136              0.00229            0.69286
# PC5                -0.19031              0.05595           -0.46667
# PC6                -0.03601              0.02654           -0.13177
# PC7                 0.10451             -0.03978            0.00128
# PC8                -0.14839              0.88793           -0.17695
# PC9                -0.12945             -0.24615           -0.13757
# PC10               -0.14852             -0.16319           -0.15041
# PC11               -0.07836             -0.08329           -0.07896
# PC12               -0.00000              0.00004           -0.00000
# PC13               -0.00044              0.00006            0.00005
# PC14               -0.00005             -0.00001            0.00000
# PC15               -0.00005              0.00004            0.00003
# PC16               -0.00003             -0.00004           -0.00005
# PC17                0.00002              0.00001            0.00001
# PC18                0.00013              0.00012            0.00012
# PC19                0.00000             -0.00002           -0.00002
# PC20               -0.00030              0.00003            0.00004
# PC21               -0.00006              0.00004            0.00000
# PC22                0.00000              0.00001           -0.00006
# PC23                0.00005              0.00007            0.00006
# PC24                0.00001              0.00008           -0.00006
# PC25               -0.00012              0.00003            0.00002
# PC26               -0.00001              0.00002           -0.00002
# PC27               -0.00011              0.00005           -0.00008
# PC28                0.00005             -0.00000            0.00001
# PC29                0.00005              0.00001           -0.00034
# PC30               -0.00005             -0.00000            0.00001
# PC31                0.00003              0.00000            0.00001
# PC32               -0.00003             -0.00001           -0.00005
# PC33                0.00006              0.00006            0.00003
# PC34               -0.00000              0.00005           -0.00003
# PC35               -0.00001             -0.00002           -0.00000
# PC36                0.00001             -0.00007           -0.00002
# PC37               -0.00004              0.00023           -0.00002
# PC38                0.00018             -0.00156            0.00020
# PC39               -0.00007              0.00014            0.00002
#
#       User_Region_Southwest  User_Region_US  User_Region_West Coast  \
# PC1                 0.00059         0.01192                -0.00672
# PC2                 0.01111         0.08466                 0.27805
# PC3                -0.00524        -0.02787                -0.17361
# PC4                 0.00116         0.01439                -0.71299
# PC5                 0.02024         0.31790                -0.42020
# PC6                 0.01069         0.74052                -0.07360
# PC7                -0.00575        -0.32703                 0.11542
# PC8                 0.08286        -0.26406                -0.17346
# PC9                 0.91493        -0.15632                -0.13729
# PC10               -0.18941        -0.15377                -0.15019
# PC11               -0.09134        -0.08009                -0.07892
# PC12                0.00000         0.00001                -0.00002
# PC13                0.00006         0.00003                 0.00007
# PC14                0.00001         0.00001                -0.00001
# PC15               -0.00002         0.00008                -0.00004
# PC16                0.00003         0.00006                -0.00001
# PC17               -0.00004         0.00006                 0.00000
# PC18                0.00012        -0.00101                 0.00013
# PC19                0.00006        -0.00007                -0.00001
# PC20                0.00004         0.00005                 0.00004
# PC21               -0.00001         0.00000                -0.00002
# PC22                0.00001         0.00000                 0.00001
# PC23                0.00006         0.00007                 0.00006
# PC24                0.00004        -0.00002                 0.00003
# PC25               -0.00002         0.00002                 0.00002
# PC26                0.00001         0.00001                -0.00002
# PC27                0.00003        -0.00006                 0.00005
# PC28               -0.00002        -0.00003                 0.00004
# PC29                0.00003         0.00002                 0.00006
# PC30                0.00002        -0.00002                -0.00002
# PC31               -0.00004         0.00003                -0.00000
# PC32               -0.00005        -0.00001                 0.00014
# PC33                0.00004         0.00004                -0.00042
# PC34               -0.00005        -0.00002                -0.00000
# PC35               -0.00001        -0.00002                -0.00001
# PC36                0.00005         0.00005                -0.00007
# PC37                0.00000        -0.00004                -0.00005
# PC38                0.00020         0.00019                 0.00019
# PC39               -0.00002        -0.00000                -0.00003
#
#       Tweet_Sentiment_negative  Tweet_Sentiment_neutral  \
# PC1                    0.07515                  0.66555
# PC2                    0.34503                 -0.22901
# PC3                    0.73267                 -0.41294
# PC4                   -0.04162                  0.00643
# PC5                   -0.01493                  0.00366
# PC6                   -0.02706                  0.00849
# PC7                   -0.04977                  0.02475
# PC8                    0.00157                 -0.00166
# PC9                    0.00035                  0.00001
# PC10                   0.00083                 -0.00065
# PC11                  -0.00019                  0.00043
# PC12                   0.00010                  0.00009
# PC13                   0.00001                 -0.00000
# PC14                   0.00004                 -0.00006
# PC15                   0.00015                 -0.00028
# PC16                   0.00007                 -0.00009
# PC17                  -0.00031                  0.00014
# PC18                   0.00008                  0.00009
# PC19                   0.00001                  0.00001
# PC20                  -0.00034                  0.00017
# PC21                   0.00001                 -0.00013
# PC22                   0.00005                 -0.00005
# PC23                   0.00007                 -0.00015
# PC24                   0.00007                 -0.00004
# PC25                  -0.00027                  0.00013
# PC26                   0.00007                 -0.00016
# PC27                   0.00006                  0.00005
# PC28                  -0.00002                  0.00000
# PC29                   0.00005                  0.00010
# PC30                   0.00006                  0.00002
# PC31                   0.00006                 -0.00013
# PC32                   0.00003                  0.00004
# PC33                   0.00010                  0.00009
# PC34                   0.00006                 -0.00012
# PC35                  -0.00023                  0.00012
# PC36                   0.00007                 -0.00002
# PC37                  -0.00015                  0.00006
# PC38                   0.00003                 -0.00009
# PC39                   0.00001                  0.00004
#
#       Tweet_Sentiment_positive
# PC1                   -0.74070
# PC2                   -0.11602
# PC3                   -0.31973
# PC4                    0.03520
# PC5                    0.01127
# PC6                    0.01857
# PC7                    0.02502
# PC8                    0.00009
# PC9                   -0.00036
# PC10                  -0.00018
# PC11                  -0.00025
# PC12                  -0.00019
# PC13                  -0.00000
# PC14                   0.00002
# PC15                   0.00014
# PC16                   0.00001
# PC17                   0.00016
# PC18                  -0.00017
# PC19                  -0.00002
# PC20                   0.00017
# PC21                   0.00012
# PC22                   0.00001
# PC23                   0.00008
# PC24                  -0.00004
# PC25                   0.00013
# PC26                   0.00009
# PC27                  -0.00011
# PC28                   0.00002
# PC29                  -0.00015
# PC30                  -0.00008
# PC31                   0.00007
# PC32                  -0.00007
# PC33                  -0.00019
# PC34                   0.00005
# PC35                   0.00011
# PC36                  -0.00005
# PC37                   0.00009
# PC38                   0.00007
# PC39                  -0.00005

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# - The ultimate goal for this project is to identify sentiment trends across US regions.
# - How do believers and deniers feel about the topics identified in our topic modeling? Does it vary by region?
# - K-means will be used to cluster the data and determine any relevant sentiment trends

# %%
# uses custom metis style sheet for notebooks
# from IPython.core.display import HTML
# HTML("""<link rel="stylesheet" href="https://soph.info/metis/nb.css" type="text/css"/>""")

# import sklearn
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Inertia and Silhouette Score

# %% [markdown]
# - Inertia (sum of squared error) and the silhouette score (cluster cohesiveness and separation) will be used to determine the ideal number of clusters
# - The peak in the silhouette score occurs at k=54 clusters, so 54 clusters will be used

# %%
inertia = []
sil_coefs = []

for k in tqdm(range(50,56)):
    km = KMeans(n_clusters=k, n_init=15, random_state=42)
    km.fit(pca39_features)
    
    inertia.append(km.inertia_)
    
    labels = km.labels_
    sil_coefs.append(metrics.silhouette_score(pca39_features, labels, metric='euclidean', random_state=42, sample_size=50000))

plt.plot(range(50,56), [i/1000000 for i in inertia])
plt.xlabel('# clusters')
plt.title('Inertia (10e6)')
plt.show()
plt.plot(range(50,56), sil_coefs)
plt.xlabel('# clusters')
plt.title('Silhouette Coefficient')
plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))

# %% [markdown]
# ## Cluster Prediction

# %%
# Compute the clusters
km54 = KMeans(n_clusters=54, random_state=42, n_init=15)
clusters_pca = km54.fit_predict(pca39_features)

# %%
pca_pred_dict = {}

for i in range(1,40):
    pca_pred_dict['PC' + str(i)] = pca39_features[:,i-1]
    if i == 39:
        pca_pred_dict['k_means_predict'] = clusters_pca

# %%
pca_pred_df = pd.DataFrame(pca_pred_dict)

# %%
pca_pred_df.k_means_predict.value_counts()
# Out:
# 1     154784
# 4     123601
# 5      93426
# 7      79396
# 6      74748
# 3      72169
# 8      68395
# 14     57090
# 17     48746
# 10     44828
# 13     43413
# 2      42051
# 9      40789
# 15     29028
# 18     23604
# 16     23442
# 19     20840
# 24     13670
# 26     12579
# 22     12068
# 21     11343
# 25     10988
# 23     10733
# 30     10487
# 31      9155
# 20      9090
# 32      8901
# 29      8740
# 27      8392
# 33      8088
# 12      7526
# 37      7252
# 11      7047
# 0       6729
# 34      5854
# 28      5134
# 40      2789
# 41      2464
# 35      2180
# 36      2161
# 44      2138
# 39      1617
# 43      1492
# 46      1365
# 38      1227
# 47      1207
# 42       840
# 45       738
# 48       219
# 49       199
# 51       169
# 53       151
# 50       140
# 52       128
# Name: k_means_predict, dtype: int64

# %% [markdown]
# ### Cluster EDA

# %% [markdown]
# - The following questions will be answered in this section:
#     - How are believers and deniers, regions, and tweet sentiment represented in each cluster?
#         - **Answer**:
#             - Every possible combination of the three features (believer vs denier, region, tweet sentiment) is represented by a cluster.
#     - How are tweet sentiments distributed throughout US regions? (i.e. are certain regions more positive, negative, etc.?)
#         - **Answer**: Although the ratios aren't exactly the same, each region has mostly positive tweets, fewer neutral tweets, and even fewer negative tweets

# %%
kmeans_df = tweets_classified_US_region[['Believer_or_Denier', 'Tweet_Sentiment', 'User_Region']].reset_index(drop=True)

# %%
kmeans_df['Cluster'] = clusters_pca

# %%
kmeans_df = kmeans_df.reset_index()

# %% [markdown]
# #### Tweets by cluster, believer vs denier, region, and sentiment

# %%
kmeans_cluster_df = kmeans_df.groupby(['Cluster', 'Believer_or_Denier', 'Tweet_Sentiment', 'User_Region']).agg({'index':'count'}).reset_index().sort_values(by=['Cluster', 'User_Region', 'Tweet_Sentiment', 'Believer_or_Denier'])
kmeans_cluster_df.rename(columns={'index': 'Tweet_Count'}, inplace=True)
kmeans_cluster_df.replace({'Believer_or_Denier': {1: 'Denier', 0: 'Believer'}}, inplace=True)

# %% [markdown]
# #### Tweet Sentiment by Region

# %%
kmeans_reg_sent_df = kmeans_df.groupby(['User_Region', 'Tweet_Sentiment']).agg({'index':'count'}).reset_index()
kmeans_reg_sent_df.head(10)
# Out:
#   User_Region Tweet_Sentiment  index
# 0      Alaska        negative    878
# 1      Alaska         neutral   1355
# 2      Alaska        positive   1836
# 3      Hawaii        negative    991
# 4      Hawaii         neutral   2330
# 5      Hawaii        positive   2379
# 6     Midwest        negative  34882
# 7     Midwest         neutral  55475
# 8     Midwest        positive  64616
# 9   Northeast        negative  77550

# %%
# Tweet count per region by sentiment

reg_sent_barplot = sns.catplot(x="User_Region", y="index", hue="Tweet_Sentiment", data=kmeans_reg_sent_df,
                height=6, kind="bar", palette="bright")
reg_sent_barplot.despine(left=True)
reg_sent_barplot.fig.suptitle("Tweet Count per Region by Sentiment")
reg_sent_barplot.set_xticklabels(rotation=45)
reg_sent_barplot.set_ylabels("Tweet Count")

# %% [markdown]
# >Although the ratios aren't exactly the same, each region has mostly positive tweets, fewer neutral tweets, and even fewer negative tweets

# %%
# region_barplot = sns.catplot(x="Cluster", y="index", hue="User_Region", data=kmeans_region_df,
#                 height=6, kind="bar", palette="bright", dodge=False)
# region_barplot.despine(left=True)
# region_barplot.fig.suptitle("Tweet Count per Cluster by Region")
# region_barplot.set_ylabels("Tweet Count")
# region_barplot.fig.set_figheight(10)
# region_barplot.fig.set_figwidth(20)

# %% [markdown]
# ## Topic Prevalence in Each Cluster

# %%
# Add cluster prediction column to cluster_df

cluster_df2 = cluster_df.copy()
cluster_df2 = cluster_df2.reset_index(drop=True)
cluster_df2['Cluster'] = clusters_pca
cluster_df2
# Out:
#          Believer_or_Denier  Contradict Trump  \
# 0                   0.00000           0.00000
# 1                   1.00000           0.00000
# 2                   0.00000           0.00000
# 3                   0.00000           0.00000
# 4                   0.00000           0.00000
# ...                     ...               ...
# 1235345             0.00000           0.00000
# 1235346             0.00000           0.00000
# 1235347             0.00000           0.00000
# 1235348             0.00000           0.00000
# 1235349             0.00000           0.00000
#
#          Donald Trump Lies (Impeachment)  Patagonia CEO Donation  \
# 0                                0.00003                 0.00000
# 1                                0.00000                 0.00000
# 2                                0.00000                 0.00000
# 3                                0.00000                 0.00000
# 4                                0.00000                 0.00000
# ...                                  ...                     ...
# 1235345                          0.00000                 0.00000
# 1235346                          0.00000                 0.00000
# 1235347                          0.00000                 0.00000
# 1235348                          0.00000                 0.00000
# 1235349                          0.00000                 0.00000
#
#          Equator Banks Act  Nov 2017 Scientific Report (Wash_Post)  \
# 0                  0.00000                                 0.00000
# 1                  0.00000                                 0.00000
# 2                  0.00000                                 0.00000
# 3                  0.00000                                 0.00000
# 4                  0.00000                                 0.00000
# ...                    ...                                     ...
# 1235345            0.00000                                 0.00000
# 1235346            0.00000                                 0.00000
# 1235347            0.00000                                 0.00000
# 1235348            0.00000                                 0.00000
# 1235349            0.00000                                 0.00000
#
#          Air and Water Quality  Sea Levels Rise  Animals at Risk  \
# 0                      0.00000          0.00003          0.00000
# 1                      0.00000          0.00000          0.00000
# 2                      0.00000          0.00000          0.00000
# 3                      0.00000          0.00000          0.00000
# 4                      0.00001          0.00000          0.00000
# ...                        ...              ...              ...
# 1235345                0.00000          0.00000          0.00000
# 1235346                0.00000          0.00000          0.00000
# 1235347                0.00000          0.00000          0.00000
# 1235348                0.00000          0.00000          0.00000
# 1235349                0.00000          0.00000          0.00000
#
#          EPA Cancels CC Scientist Talks (NY_Times)  Al Gore  \
# 0                                          0.00002  0.00000
# 1                                          0.00000  0.00000
# 2                                          0.00000  0.00002
# 3                                          0.00000  0.00000
# 4                                          0.00000  0.00000
# ...                                            ...      ...
# 1235345                                    0.00000  0.00000
# 1235346                                    0.00000  0.00000
# 1235347                                    0.00000  0.00000
# 1235348                                    0.00000  0.00000
# 1235349                                    0.00000  0.00000
#
#          Obama Era Policies  Women Involvement  BlackRock_Petition  \
# 0                   0.00001            0.00000             0.00000
# 1                   0.00000            0.00000             0.00000
# 2                   0.00000            0.00000             0.00000
# 3                   0.00000            0.00000             0.00000
# 4                   0.00000            0.00000             0.00000
# ...                     ...                ...                 ...
# 1235345             0.00000            0.00000             0.00000
# 1235346             0.00000            0.00000             0.00000
# 1235347             0.00000            0.00000             0.00000
# 1235348             0.00000            0.00000             0.00000
# 1235349             0.00000            0.00000             0.00000
#
#          Animal Protection  Mini Ice Age  Human Impact on Earth  \
# 0                  0.00000       0.00000                0.00002
# 1                  0.00004       0.00000                0.00000
# 2                  0.00000       0.00000                0.00000
# 3                  0.00000       0.00000                0.00000
# 4                  0.00000       0.00000                0.00000
# ...                    ...           ...                    ...
# 1235345            0.00000       0.00000                0.00000
# 1235346            0.00000       0.00000                0.00000
# 1235347            0.00000       0.00000                0.00000
# 1235348            0.00000       0.00000                0.00000
# 1235349            0.00000       0.00000                0.00000
#
#          Coal Conference  Oil Company Lawsuit  Cost of Climate Change  \
# 0                0.00001              0.00204                 0.00000
# 1                0.00000              0.10203                 0.00000
# 2                0.00000              0.00000                 0.00000
# 3                0.00000              0.00000                 0.00000
# 4                0.00000              0.00008                 0.00000
# ...                  ...                  ...                     ...
# 1235345          0.00000              0.00000                 0.00000
# 1235346          0.00000              0.00000                 0.00000
# 1235347          0.00000              0.00000                 0.00000
# 1235348          0.00000              0.00001                 0.00000
# 1235349          0.00000              0.00000                 0.00000
#
#          Scott Pruitt  Activism  Teach Climate Change  CO2 Emissions  \
# 0             0.00002   0.00000               0.00000        0.00002
# 1             0.00000   0.00000               0.00000        0.00000
# 2             0.00008   0.00000               0.00000        0.00000
# 3             0.00000   0.00000               0.00000        0.00000
# 4             0.00000   0.00000               0.00000        0.00000
# ...               ...       ...                   ...            ...
# 1235345       0.00000   0.00000               0.00000        0.00000
# 1235346       0.00000   0.00000               0.00000        0.00000
# 1235347       0.00000   0.00000               0.00000        0.00000
# 1235348       0.00000   0.00000               0.00000        0.00000
# 1235349       0.00000   0.00000               0.00000        0.00000
#
#          Energy Innovation (Carbon Dividend)  Auto Alliance  \
# 0                                    0.00000        0.00000
# 1                                    0.00000        0.00000
# 2                                    0.00000        0.00000
# 3                                    0.00000        0.00000
# 4                                    0.00000        0.00000
# ...                                      ...            ...
# 1235345                              0.00000        0.00000
# 1235346                              0.00000        0.00000
# 1235347                              0.00000        0.00000
# 1235348                              0.00000        0.00000
# 1235349                              0.00000        0.00000
#
#          EPA Yanks CC Conference (Wash_Post)  Paris Agreement  \
# 0                                    0.00000          0.00000
# 1                                    0.00000          0.00000
# 2                                    0.00000          0.00000
# 3                                    0.00000          0.00000
# 4                                    0.00000          0.00000
# ...                                      ...              ...
# 1235345                              0.00000          0.00000
# 1235346                              0.00000          0.00000
# 1235347                              0.00000          0.00000
# 1235348                              0.00000          0.00000
# 1235349                              0.00000          0.00000
#
#          Greenhouse Gas Emissions  Ralph B Alexander  Earth Day  \
# 0                         0.00001            0.00000    0.00000
# 1                         0.00000            0.00000    0.00000
# 2                         0.00000            0.00000    0.00001
# 3                         0.00000            0.00000    0.00000
# 4                         0.00000            0.00000    0.00000
# ...                           ...                ...        ...
# 1235345                   0.00000            0.00000    0.00000
# 1235346                   0.00000            0.00000    0.00000
# 1235347                   0.00000            0.00000    0.00000
# 1235348                   0.00000            0.00000    0.00004
# 1235349                   0.00000            0.00000    0.00000
#
#          User_Region_Alaska  User_Region_Hawaii  User_Region_Midwest  \
# 0                         0                   0                    0
# 1                         0                   0                    0
# 2                         0                   0                    0
# 3                         0                   0                    0
# 4                         0                   0                    0
# ...                     ...                 ...                  ...
# 1235345                   0                   0                    0
# 1235346                   0                   0                    0
# 1235347                   0                   0                    0
# 1235348                   0                   0                    1
# 1235349                   0                   0                    1
#
#          User_Region_Northeast  User_Region_Rockies  User_Region_South  \
# 0                            1                    0                  0
# 1                            0                    0                  0
# 2                            1                    0                  0
# 3                            0                    0                  1
# 4                            1                    0                  0
# ...                        ...                  ...                ...
# 1235345                      0                    0                  1
# 1235346                      0                    0                  0
# 1235347                      1                    0                  0
# 1235348                      0                    0                  0
# 1235349                      0                    0                  0
#
#          User_Region_Southwest  User_Region_US  User_Region_West Coast  \
# 0                            0               0                       0
# 1                            0               0                       1
# 2                            0               0                       0
# 3                            0               0                       0
# 4                            0               0                       0
# ...                        ...             ...                     ...
# 1235345                      0               0                       0
# 1235346                      0               0                       1
# 1235347                      0               0                       0
# 1235348                      0               0                       0
# 1235349                      0               0                       0
#
#          Tweet_Sentiment_negative  Tweet_Sentiment_neutral  \
# 0                               0                        1
# 1                               0                        1
# 2                               1                        0
# 3                               0                        0
# 4                               0                        1
# ...                           ...                      ...
# 1235345                         0                        0
# 1235346                         0                        1
# 1235347                         0                        0
# 1235348                         0                        0
# 1235349                         0                        1
#
#          Tweet_Sentiment_positive  Cluster
# 0                               0        4
# 1                               0       33
# 2                               0        8
# 3                               1        7
# 4                               0        4
# ...                           ...      ...
# 1235345                         1        7
# 1235346                         0        6
# 1235347                         1        1
# 1235348                         1       14
# 1235349                         0       17
#
# [1235350 rows x 44 columns]

# %% [markdown]
# ### Determine how prevelant each topic is within each cluster

# %%
cluster_topic_df = cluster_df2.groupby('Cluster').agg({'Contradict Trump': 'sum',
                                                       'Donald Trump Lies (Impeachment)': 'sum',
                                                       'Patagonia CEO Donation': 'sum',
                                                       'Equator Banks Act': 'sum',
                                                       'Nov 2017 Scientific Report (Wash_Post)': 'sum',
                                                       'Air and Water Quality': 'sum',
                                                       'Sea Levels Rise': 'sum',
                                                       'Animals at Risk': 'sum',
                                                       'EPA Cancels CC Scientist Talks (NY_Times)': 'sum',
                                                       'Al Gore': 'sum',
                                                       'Obama Era Policies': 'sum',
                                                       'Women Involvement': 'sum',
                                                       'BlackRock_Petition': 'sum',
                                                       'Animal Protection': 'sum',
                                                       'Mini Ice Age': 'sum',
                                                       'Human Impact on Earth': 'sum',
                                                       'Coal Conference': 'sum',
                                                       'Oil Company Lawsuit': 'sum',
                                                       'Cost of Climate Change': 'sum',
                                                       'Scott Pruitt': 'sum',
                                                       'Activism': 'sum',
                                                       'Teach Climate Change': 'sum',
                                                       'CO2 Emissions': 'sum',
                                                       'Energy Innovation (Carbon Dividend)': 'sum',
                                                       'Auto Alliance': 'sum',
                                                       'EPA Yanks CC Conference (Wash_Post)': 'sum',
                                                       'Paris Agreement': 'sum',
                                                       'Greenhouse Gas Emissions': 'sum',
                                                       'Ralph B Alexander': 'sum',
                                                       'Earth Day': 'sum'})

# %%
cluster_topic_dist_df = cluster_topic_df.stack().reset_index()

# %%
cluster_topic_dist_df.columns = ['Cluster', 'Topic', 'Topic Prevalence']

# %% [markdown]
# ### Calculate topic prevalance percentage within each cluster

# %%
topic_prevalence_df = cluster_topic_dist_df.groupby('Cluster').agg({'Topic Prevalence':'sum'})

# %%
topic_prevalence_list = []

for sum in topic_prevalence_df['Topic Prevalence'].values:
    prevalence_prelist = 30*[sum]
    topic_prevalence_list.extend(prevalence_prelist)

# %%
cluster_topic_dist_df['Topic Sum'] = topic_prevalence_list

# %%
cluster_topic_dist_df['Topic Prevalence %'] = 100*cluster_topic_dist_df['Topic Prevalence']/cluster_topic_dist_df['Topic Sum']

# %%
cluster_topic_dist_sort_df = cluster_topic_dist_df.sort_values(by=['Cluster', 'Topic Prevalence %'], ascending=[True, False])

# %% [markdown]
# ### Create dataframe showing top 5 topics for each cluster

# %%
top5_df = cluster_topic_dist_sort_df[cluster_topic_dist_sort_df.Cluster == 0].head(5).reset_index()

for k in range(1,54):
    top5_df = top5_df.append(cluster_topic_dist_sort_df[cluster_topic_dist_sort_df.Cluster == k].head(5), ignore_index=True, sort=False)
    
top5_df.drop('index', axis=1, inplace=True)

# %%
top5_df
# Out:
#      Cluster                Topic  Topic Prevalence %
# 0          0              Al Gore            52.65351
# 1          0         Mini Ice Age            19.82788
# 2          0  Oil Company Lawsuit            15.34106
# 3          0      Coal Conference             2.42665
# 4          0      Sea Levels Rise             1.55643
# ..       ...                  ...                 ...
# 265       53              Al Gore            35.47027
# 266       53  Oil Company Lawsuit            28.62381
# 267       53         Mini Ice Age            20.33253
# 268       53      Sea Levels Rise            10.36920
# 269       53            Earth Day             1.27088
#
# [270 rows x 3 columns]

# %%
top5_topic_df = top5_df[['Cluster', 'Topic', 'Topic Prevalence %']]    \
                       .merge(kmeans_cluster_df, how='left', on='Cluster')    \
                       .groupby(['User_Region', 'Believer_or_Denier', 'Tweet_Sentiment', 'Tweet_Count', 'Topic'])    \
                       .agg({'Topic Prevalence %':'sum', 'Cluster': 'sum'})    \
                       .sort_values(by=['Cluster', 'Topic Prevalence %'], ascending=[True, False])

top5_topic_df.drop('Cluster', axis=1, inplace=True)

# %%
top5_topic_df
# Out:
#                                                                                                       Topic Prevalence %
# User_Region Believer_or_Denier Tweet_Sentiment Tweet_Count Topic
# Midwest     Denier             neutral         6729        Al Gore                                              52.65351
#                                                            Mini Ice Age                                         19.82788
#                                                            Oil Company Lawsuit                                  15.34106
#                                                            Coal Conference                                       2.42665
#                                                            Sea Levels Rise                                       1.55643
# Northeast   Believer           positive        154784      Donald Trump Lies (Impeachment)                      12.64078
#                                                            Contradict Trump                                     11.40679
#                                                            Animal Protection                                    11.31633
#                                                            Greenhouse Gas Emissions                              8.84653
#                                                            Sea Levels Rise                                       7.99453
# South       Believer           negative        42051       Nov 2017 Scientific Report (Wash_Post)               17.72513
#                                                            Cost of Climate Change                               13.44723
#                                                            Scott Pruitt                                         11.18438
#                                                            Sea Levels Rise                                      10.11406
#                                                            Women Involvement                                     8.13407
#                                neutral         72169       Equator Banks Act                                     9.28364
#                                                            Human Impact on Earth                                 9.27144
#                                                            Patagonia CEO Donation                                8.46937
#                                                            Coal Conference                                       7.40534
#                                                            EPA Cancels CC Scientist Talks (NY_Times)             7.35661
# Northeast   Believer           neutral         123601      Donald Trump Lies (Impeachment)                      16.95047
#                                                            EPA Cancels CC Scientist Talks (NY_Times)             8.64163
#                                                            Patagonia CEO Donation                                7.43179
#                                                            Equator Banks Act                                     7.35344
#                                                            Coal Conference                                       6.58719
# West Coast  Believer           positive        93426       Activism                                             32.94004
#                                                            Contradict Trump                                      9.96278
#                                                            Coal Conference                                       7.17269
#                                                            Energy Innovation (Carbon Dividend)                   6.65660
#                                                            Sea Levels Rise                                       6.50109
#                                neutral         74748       Equator Banks Act                                    12.54953
#                                                            Patagonia CEO Donation                               10.83761
#                                                            Auto Alliance                                         7.55853
#                                                            EPA Cancels CC Scientist Talks (NY_Times)             7.02177
#                                                            Coal Conference                                       6.64020
# South       Believer           positive        79396       Obama Era Policies                                   29.66498
#                                                            Animal Protection                                     9.63216
#                                                            Contradict Trump                                      8.95430
#                                                            Sea Levels Rise                                       6.81181
#                                                            Coal Conference                                       6.50899
# Northeast   Believer           negative        68395       Animals at Risk                                      28.89599
#                                                            Women Involvement                                    15.04556
#                                                            Nov 2017 Scientific Report (Wash_Post)                9.52600
#                                                            Donald Trump Lies (Impeachment)                       7.72427
#                                                            Cost of Climate Change                                6.33400
# US          Believer           neutral         40789       Human Impact on Earth                                 9.67838
#                                                            Coal Conference                                       9.10808
#                                                            EPA Cancels CC Scientist Talks (NY_Times)             7.33846
#                                                            Sea Levels Rise                                       7.19695
#                                                            EPA Yanks CC Conference (Wash_Post)                   7.15101
#                                positive        44828       Air and Water Quality                                54.48208
#                                                            Contradict Trump                                      5.91925
#                                                            Coal Conference                                       5.31242
#                                                            Animal Protection                                     4.34754
#                                                            Oil Company Lawsuit                                   4.28973
# West Coast  Denier             negative        7047        Al Gore                                              30.46273
#                                                            Mini Ice Age                                         24.57696
#                                                            Oil Company Lawsuit                                  14.67376
#                                                            Sea Levels Rise                                       6.85016
#                                                            Earth Day                                             5.63901
# Midwest     Denier             positive        7526        Al Gore                                              31.97986
#                                                            Mini Ice Age                                         28.22770
#                                                            Oil Company Lawsuit                                  20.29895
#                                                            Scott Pruitt                                          3.78255
#                                                            Coal Conference                                       3.77054
# West Coast  Believer           negative        43413       Nov 2017 Scientific Report (Wash_Post)               18.50138
#                                                            Cost of Climate Change                               13.37103
#                                                            Scott Pruitt                                         12.10505
#                                                            Sea Levels Rise                                       8.24224
#                                                            Coal Conference                                       7.49928
# Midwest     Believer           positive        57090       Coal Conference                                      12.41034
#                                                            Contradict Trump                                     12.40179
#                                                            Teach Climate Change                                 10.79088
#                                                            Greenhouse Gas Emissions                              9.23867
#                                                            Energy Innovation (Carbon Dividend)                   9.09757
#                                negative        29028       Nov 2017 Scientific Report (Wash_Post)               21.95285
#                                                            Scott Pruitt                                         13.16395
#                                                            Cost of Climate Change                               10.31762
#                                                            Women Involvement                                     9.35372
#                                                            Coal Conference                                       8.61038
# Rockies     Believer           positive        23442       CO2 Emissions                                        21.50772
#                                                            Energy Innovation (Carbon Dividend)                  10.71128
#                                                            Greenhouse Gas Emissions                              8.56101
#                                                            Contradict Trump                                      7.61933
#                                                            Sea Levels Rise                                       6.88315
# Midwest     Believer           neutral         48746       Ralph B Alexander                                    31.98196
#                                                            Equator Banks Act                                     7.58525
#                                                            Patagonia CEO Donation                                6.29097
#                                                            BlackRock_Petition                                    5.92432
#                                                            Human Impact on Earth                                 5.26563
# US          Believer           negative        23604       Nov 2017 Scientific Report (Wash_Post)               17.06941
#                                                            Cost of Climate Change                               15.10382
#                                                            Scott Pruitt                                         11.53754
#                                                            Coal Conference                                       8.00064
#                                                            Sea Levels Rise                                       7.57092
# Rockies     Believer           neutral         20840       CO2 Emissions                                        51.95562
#                                                            Greenhouse Gas Emissions                              6.64466
#                                                            Patagonia CEO Donation                                4.54528
#                                                            Equator Banks Act                                     4.21219
#                                                            Sea Levels Rise                                       3.69836
# Southwest   Believer           neutral         9090        Equator Banks Act                                    13.02111
#                                                            Human Impact on Earth                                10.83440
#                                                            Patagonia CEO Donation                                9.51464
#                                                            Auto Alliance                                         9.50342
#                                                            EPA Cancels CC Scientist Talks (NY_Times)             8.66267
# Rockies     Believer           negative        11343       CO2 Emissions                                        20.59619
#                                                            Nov 2017 Scientific Report (Wash_Post)               13.09226
#                                                            Cost of Climate Change                               12.46236
#                                                            Scott Pruitt                                          9.26919
#                                                            Sea Levels Rise                                       6.69581
# Northeast   Denier             positive        12068       Oil Company Lawsuit                                  33.29603
#                                                            Al Gore                                              28.91923
#                                                            Mini Ice Age                                         17.14645
#                                                            Scott Pruitt                                          4.70873
#                                                            Earth Day                                             2.96235
# Southwest   Believer           positive        10733       Contradict Trump                                     13.76307
#                                                            Teach Climate Change                                 11.17649
#                                                            Coal Conference                                      11.11493
#                                                            Greenhouse Gas Emissions                             10.03462
#                                                            Mini Ice Age                                          8.37099
# South       Denier             positive        13670       Al Gore                                              36.05457
#                                                            Mini Ice Age                                         28.33716
#                                                            Oil Company Lawsuit                                  18.73312
#                                                            Coal Conference                                       3.50895
#                                                            Earth Day                                             3.45197
#                                negative        10988       Al Gore                                              39.41123
#                                                            Mini Ice Age                                         30.20692
#                                                            Oil Company Lawsuit                                  14.14857
#                                                            Earth Day                                             3.41907
#                                                            Sea Levels Rise                                       2.48123
#                                neutral         12579       Al Gore                                              53.98422
#                                                            Mini Ice Age                                         21.80901
#                                                            Oil Company Lawsuit                                  12.55216
#                                                            Scott Pruitt                                          2.04404
#                                                            Earth Day                                             1.92826
# US          Denier             neutral         8392        Al Gore                                              42.62747
#                                                            Mini Ice Age                                         24.39676
#                                                            Oil Company Lawsuit                                  14.43591
#                                                            Scott Pruitt                                          4.27792
#                                                            Sea Levels Rise                                       2.52275
# Southwest   Believer           negative        5134        Nov 2017 Scientific Report (Wash_Post)               26.14417
#                                                            Women Involvement                                    13.59875
#                                                            Cost of Climate Change                               11.57901
#                                                            Sea Levels Rise                                       7.00198
#                                                            Scott Pruitt                                          6.65169
# US          Denier             positive        8740        Al Gore                                              33.23368
#                                                            Mini Ice Age                                         27.75828
#                                                            Oil Company Lawsuit                                  23.31618
#                                                            Coal Conference                                       2.94406
#                                                            Earth Day                                             2.74083
# Northeast   Denier             neutral         10487       Al Gore                                              44.99119
#                                                            Oil Company Lawsuit                                  19.39369
#                                                            Mini Ice Age                                         13.84750
#                                                            Donald Trump Lies (Impeachment)                       4.40584
#                                                            Coal Conference                                       3.17604
#                                negative        9155        Al Gore                                              35.97672
#                                                            Mini Ice Age                                         23.47428
#                                                            Oil Company Lawsuit                                  18.88460
#                                                            Scott Pruitt                                          3.86341
#                                                            Earth Day                                             3.79306
# West Coast  Denier             positive        8901        Al Gore                                              30.17544
#                                                            Oil Company Lawsuit                                  26.97378
#                                                            Mini Ice Age                                         22.39997
#                                                            Coal Conference                                       4.17766
#                                                            Earth Day                                             3.30884
#                                neutral         8088        Al Gore                                              41.33794
#                                                            Mini Ice Age                                         21.85281
#                                                            Oil Company Lawsuit                                  20.24573
#                                                            Scott Pruitt                                          3.16221
#                                                            Coal Conference                                       2.87177
# Midwest     Denier             negative        5854        Al Gore                                              36.66430
#                                                            Mini Ice Age                                         27.65897
#                                                            Oil Company Lawsuit                                  12.76277
#                                                            Sea Levels Rise                                       4.62167
#                                                            Scott Pruitt                                          4.15676
# Hawaii      Believer           positive        2180        Sea Levels Rise                                      25.11183
#                                                            Coal Conference                                      10.82324
#                                                            Contradict Trump                                      9.22087
#                                                            Oil Company Lawsuit                                   7.42908
#                                                            Greenhouse Gas Emissions                              7.00169
#                                neutral         2161        Equator Banks Act                                    16.57694
#                                                            Coal Conference                                      13.34689
#                                                            Patagonia CEO Donation                               12.78147
#                                                            Sea Levels Rise                                       9.39268
#                                                            Paris Agreement                                       7.23443
# US          Denier             negative        7252        Al Gore                                              34.13059
#                                                            Mini Ice Age                                         26.95502
#                                                            Oil Company Lawsuit                                  14.96780
#                                                            Scott Pruitt                                          6.25916
#                                                            Sea Levels Rise                                       4.45767
# Alaska      Believer           neutral         1227        Equator Banks Act                                    17.84459
#                                                            Auto Alliance                                        14.70993
#                                                            Patagonia CEO Donation                               11.89837
#                                                            EPA Yanks CC Conference (Wash_Post)                  11.08515
#                                                            Coal Conference                                       9.23789
#                                positive        1617        Contradict Trump                                     24.38756
#                                                            Coal Conference                                      14.37257
#                                                            Human Impact on Earth                                11.53948
#                                                            Al Gore                                               9.90977
#                                                            Oil Company Lawsuit                                   9.73716
# Rockies     Denier             positive        2789        Al Gore                                              30.79086
#                                                            Oil Company Lawsuit                                  29.11492
#                                                            Mini Ice Age                                         24.29462
#                                                            Sea Levels Rise                                       4.47469
#                                                            Coal Conference                                       3.33596
#                                neutral         2464        Al Gore                                              38.92095
#                                                            Mini Ice Age                                         26.69586
#                                                            Oil Company Lawsuit                                  22.04985
#                                                            Sea Levels Rise                                       2.75634
#                                                            Scott Pruitt                                          2.66972
# Hawaii      Believer           negative        840         Nov 2017 Scientific Report (Wash_Post)               19.14307
#                                                            Scott Pruitt                                         16.33476
#                                                            Women Involvement                                    13.91960
#                                                            Coal Conference                                      10.83293
#                                                            EPA Cancels CC Scientist Talks (NY_Times)             9.00278
# Southwest   Denier             positive        1492        Al Gore                                              32.25330
#                                                            Oil Company Lawsuit                                  26.00933
#                                                            Mini Ice Age                                         22.51113
#                                                            Coal Conference                                       3.39723
#                                                            Scott Pruitt                                          3.27189
# Rockies     Denier             negative        2138        Mini Ice Age                                         33.95659
#                                                            Al Gore                                              29.75176
#                                                            Oil Company Lawsuit                                  13.98572
#                                                            Sea Levels Rise                                       4.83855
#                                                            Scott Pruitt                                          4.63734
# Alaska      Believer           negative        738         Nov 2017 Scientific Report (Wash_Post)               26.12974
#                                                            Oil Company Lawsuit                                  13.56312
#                                                            Scott Pruitt                                         10.06468
#                                                            Cost of Climate Change                                8.98099
#                                                            Mini Ice Age                                          8.94273
# Southwest   Denier             neutral         1365        Al Gore                                              48.17456
#                                                            Mini Ice Age                                         25.04256
#                                                            Oil Company Lawsuit                                  11.12540
#                                                            Earth Day                                             5.13751
#                                                            Sea Levels Rise                                       2.79113
#                                negative        1207        Al Gore                                              45.57096
#                                                            Mini Ice Age                                         30.77610
#                                                            Oil Company Lawsuit                                   8.89912
#                                                            Sea Levels Rise                                       2.77271
#                                                            Contradict Trump                                      2.42267
# Alaska      Denier             positive        219         Mini Ice Age                                         32.27241
#                                                            Al Gore                                              19.87731
#                                                            Oil Company Lawsuit                                  17.95677
#                                                            Coal Conference                                      11.24305
#                                                            Scott Pruitt                                          8.95662
# Hawaii      Denier             positive        199         Mini Ice Age                                         69.12117
#                                                            Al Gore                                              10.80620
#                                                            Oil Company Lawsuit                                   9.80148
#                                                            Coal Conference                                       3.21874
#                                                            Obama Era Policies                                    1.96950
# Alaska      Denier             negative        140         Mini Ice Age                                         46.72937
#                                                            Al Gore                                              19.91969
#                                                            Coal Conference                                      15.09458
#                                                            Greenhouse Gas Emissions                             13.21780
#                                                            Earth Day                                             2.28680
# Hawaii      Denier             neutral         169         Al Gore                                              55.45993
#                                                            Oil Company Lawsuit                                  19.35847
#                                                            Earth Day                                             7.82913
#                                                            Patagonia CEO Donation                                7.20773
#                                                            Mini Ice Age                                          4.74056
# Alaska      Denier             neutral         128         Al Gore                                              47.89134
#                                                            Mini Ice Age                                         27.87408
#                                                            Patagonia CEO Donation                                5.90200
#                                                            Coal Conference                                       5.51929
#                                                            Scott Pruitt                                          4.72760
# Hawaii      Denier             negative        151         Al Gore                                              35.47027
#                                                            Oil Company Lawsuit                                  28.62381
#                                                            Mini Ice Age                                         20.33253
#                                                            Sea Levels Rise                                      10.36920
#                                                            Earth Day                                             1.27088

# %% [markdown]
# ## Cluster Summary

# %% [markdown]
# - Deniers across every US region are primarily concerned with 3 topics:
#     - Al Gore
#     - Oil company lawsuit
#     - Mini Ice Age
# - Believers across the country discuss a wider range of topics, summarized below:
#     - Northeast
#         - Donald Trump lying about climate change
#         - Animals at risk due to climate change
#     - West Coast
#         - Activism and progressive policies
#         - Scott Pruitt and the cost of climate change
#     - Midwest
#         - 2017 report discussing the dangers of climate change
#         - Ralph Alexander
#     - Rockies
#         - CO2 and greenhouse gas emissions
#     - Southwest
#         - 2017 report discussing the dangers of climate change
#     - South
#         - Obama Era Policies
#     - Alaska
#         - Reports contradicting Trump administration regarding human impact on climate change
#         - 2017 report discussing the dangers of climate change
#     - Hawaii
#         - Sea level rise

# %%
# # Plot Topic prevalence within each cluster

# with sns.plotting_context("notebook", font_scale=2.25):
#     topic_barplot = sns.catplot(x="Topic Prevalence %", y="Cluster", hue="Topic", data=cluster_topic_dist_df,
#                                 legend_out=False, orient="h", kind="bar", palette="bright")
#     # topic_barplot.fig.suptitle("Topic Distribution by Cluster")
#     topic_barplot.fig.set_figwidth(60)
#     topic_barplot.fig.set_figheight(200)

# %% [markdown]
# ---

# %%
# cluster_dist_dict = defaultdict(list)

# for column in cluster_topic_df.columns:
#     for cluster in range(5):
#         cluster_dist_dict[str(cluster)]    \
#         .append(round(100*cluster_topic_df[column][cluster]/
#                       sum(cluster_topic_df[column].values),1))

# %%
# topic_cluster_df = pd.DataFrame(data = cluster_dist_dict, index = cluster_topic_df.columns)

# %%
# topic_cluster_df = topic_cluster_df.stack().reset_index()

# %%
# topic_cluster_df.columns = ['Topic', 'Cluster', '% of Topic']

# %%
# topic_barplot = sns.catplot(x="% of Topic", y="Topic", hue="Cluster", data=topic_cluster_df,
#                             legend_out=False, orient="h", kind="bar", palette="bright")
# # topic_barplot.fig.suptitle("Cluster Distribution by Topic")
# topic_barplot.fig.set_figwidth(60)
# topic_barplot.fig.set_figheight(50)

# %% [markdown]
# ---

# %% [markdown]
# # Cluster Plot Assuming 3 Principal Components

# %% [markdown]
# - Strictly for visualization purposes

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
pca3, pca3_features = pca_function(cluster_scaled, 3, 42)

# %%
# Compute the clusters
km5 = KMeans(n_clusters=54, random_state=42, n_init=10)
clusters = km5.fit_predict(pca3_features)

# %%
def display_cluster(X,km=[],num_clusters=0):
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    color = 'brgcmyk'
    alpha = 0.5
    s = 20
    
    if num_clusters == 0:
        plt.scatter(X[:,0],X[:,1], c = color[0],alpha = alpha,s = s)
    else:
        try:
            for i in range(num_clusters):
                ax.scatter(X[km.labels_==i,0],X[km.labels_==i,1], X[km.labels_==i,2], c = color[i],alpha = alpha,s=s)
                ax.scatter(km.cluster_centers_[i][0],km.cluster_centers_[i][1], km.cluster_centers_[i][2], c = color[i], marker = 'x', s = 100)
        except:
            pass

# %%
display_cluster(pca3_features, km5, 54)

# %% [markdown]
# ---

# %%
# t_SNE

# %%
# from sklearn.manifold import TSNE

# %%
# # Project the data: this step will take several seconds
# tsne = TSNE(n_components=3, init='random', random_state=42)
# cluster_tsne = tsne.fit_transform(pca_features)

# %%
# # Compute the clusters
# kmeans = KMeans(n_clusters=7, random_state=42, n_init=10)
# clusters = kmeans.fit_predict(cluster_tsne)
